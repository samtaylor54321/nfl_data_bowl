# %%
import os
TRAIN_ABLE_FALSE=True
if TRAIN_ABLE_FALSE:
    os.environ['CUDA_VISIBLE_DEVICES'] = "1"
import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nfl-big-data-bowl-2020/train.csv
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/competition.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/test.csv.encrypted
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/__init__.py
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/sample_submission.csv.encrypted

# %%
# train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
if TRAIN_OFFLINE:
    train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})
else:
    train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
train.head()
# Out:
#        GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0  2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1  2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2  2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3  2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4  2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
#
#    Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# 0        81.99  177.18   496723       Eric Berry            29    2017
# 1        27.61  198.70  2495116     Allen Bailey            97    2017
# 2         3.01  202.73  2495493   Justin Houston            50    2017
# 3       359.77  105.64  2506353  Derrick Johnson            56    2017
# 4        12.63  164.31  2530794       Ron Parker            38    2017
#
#    YardLine  Quarter GameClock PossessionTeam  Down  Distance FieldPosition  \
# 0        35        1  14:14:00             NE     3         2            NE
# 1        35        1  14:14:00             NE     3         2            NE
# 2        35        1  14:14:00             NE     3         2            NE
# 3        35        1  14:14:00             NE     3         2            NE
# 4        35        1  14:14:00             NE     3         2            NE
#
#    HomeScoreBeforePlay  VisitorScoreBeforePlay  NflIdRusher OffenseFormation  \
# 0                    0                       0      2543773          SHOTGUN
# 1                    0                       0      2543773          SHOTGUN
# 2                    0                       0      2543773          SHOTGUN
# 3                    0                       0      2543773          SHOTGUN
# 4                    0                       0      2543773          SHOTGUN
#
#    OffensePersonnel  DefendersInTheBox  DefensePersonnel PlayDirection  \
# 0  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 1  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 2  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 3  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
# 4  1 RB, 1 TE, 3 WR                6.0  2 DL, 3 LB, 6 DB          left
#
#                 TimeHandoff                  TimeSnap  Yards PlayerHeight  \
# 0  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
# 1  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 2  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 3  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-3
# 4  2017-09-08T00:44:06.000Z  2017-09-08T00:44:05.000Z      8          6-0
#
#    PlayerWeight PlayerBirthDate PlayerCollegeName Position HomeTeamAbbr  \
# 0           212      12/29/1988         Tennessee       SS           NE
# 1           288      03/25/1989             Miami       DE           NE
# 2           270      01/21/1989           Georgia       DE           NE
# 3           245      11/22/1982             Texas      ILB           NE
# 4           206      08/17/1987          Newberry       FS           NE
#
#   VisitorTeamAbbr  Week           Stadium        Location StadiumType  \
# 0              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 1              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 2              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 3              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
# 4              KC     1  Gillette Stadium  Foxborough, MA     Outdoor
#
#          Turf     GameWeather  Temperature  Humidity WindSpeed WindDirection
# 0  Field Turf  Clear and warm         63.0      77.0         8            SW
# 1  Field Turf  Clear and warm         63.0      77.0         8            SW
# 2  Field Turf  Clear and warm         63.0      77.0         8            SW
# 3  Field Turf  Clear and warm         63.0      77.0         8            SW
# 4  Field Turf  Clear and warm         63.0      77.0         8            SW

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
    # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
    # train["Week_ob"] = train["Week"].astype("object")
    # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %% [markdown]
# ## Functions for anchoring offense moving left from {0,0}

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Weather
        df['GameWeather_process'] = df['GameWeather'].str.lower()
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
        df['GameWeather_process'] = df['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
        df['GameWeather_dense'] = df['GameWeather_process'].apply(map_weather)
        add_new_feas.append('GameWeather_dense')
#         ## Rusher
#         train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
#         train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
#         temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
#         train = train.merge(temp, on = "PlayId")
#         train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

        ## dense -> categorical
#         train["Quarter_ob"] = train["Quarter"].astype("object")
#         train["Down_ob"] = train["Down"].astype("object")
#         train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
#         train["YardLine_ob"] = train["YardLine"].astype("object")
        # train["DefendersInTheBox_ob"] = train["DefendersInTheBox"].astype("object")
        # train["Week_ob"] = train["Week"].astype("object")
        # train["TimeDelta_ob"] = train["TimeDelta"].astype("object")


        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
        
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()
#         static_features['DefendersInTheBox'] = static_features['DefendersInTheBox'].fillna(np.mean(static_features['DefendersInTheBox']))
        static_features.fillna(-999,inplace=True)
#         for i in add_new_feas:
#             static_features[i] = static_features[i].fillna(np.mean(static_features[i]))
            

        return static_features


    def combine_features(relative_to_back, defense, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats, static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 11s, sys: 6.56 s, total: 5min 17s
# Wall time: 5min 17s

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 30) (3476, 30)
# (19695, 199) (3476, 199)

# %% [markdown]
# # Let's build NN

# %% [markdown]
# Below class Metric based entirely on: https://www.kaggle.com/kingychiu/keras-nn-starter-crps-early-stopping
# <br></br>
# Below early stopping entirely based on: https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/112868#latest-656533

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 2s 117us/step - loss: 5.5957
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08255, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 5.1237
#
# Epoch 00002: CRPS_score_val improved from 0.08255 to 0.07750, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 4.7196
#
# Epoch 00003: CRPS_score_val improved from 0.07750 to 0.06429, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 4.3261
#
# Epoch 00004: CRPS_score_val improved from 0.06429 to 0.04392, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 3.9260
#
# Epoch 00005: CRPS_score_val improved from 0.04392 to 0.02757, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 3.5992
#
# Epoch 00006: CRPS_score_val improved from 0.02757 to 0.01949, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 3.3327
#
# Epoch 00007: CRPS_score_val improved from 0.01949 to 0.01595, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 82us/step - loss: 3.1422
#
# Epoch 00008: CRPS_score_val improved from 0.01595 to 0.01449, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 3.0301
#
# Epoch 00009: CRPS_score_val improved from 0.01449 to 0.01387, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.9627
#
# Epoch 00010: CRPS_score_val improved from 0.01387 to 0.01356, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.9189
#
# Epoch 00011: CRPS_score_val improved from 0.01356 to 0.01345, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.8746
#
# Epoch 00012: CRPS_score_val improved from 0.01345 to 0.01336, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.8467
#
# Epoch 00013: CRPS_score_val improved from 0.01336 to 0.01329, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.8336
#
# Epoch 00014: CRPS_score_val improved from 0.01329 to 0.01324, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.8105
#
# Epoch 00015: CRPS_score_val improved from 0.01324 to 0.01319, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7997
#
# Epoch 00016: CRPS_score_val improved from 0.01319 to 0.01315, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7855
#
# Epoch 00017: CRPS_score_val improved from 0.01315 to 0.01313, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7707
#
# Epoch 00018: CRPS_score_val improved from 0.01313 to 0.01311, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.7683
#
# Epoch 00019: CRPS_score_val improved from 0.01311 to 0.01308, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7609
#
# Epoch 00020: CRPS_score_val improved from 0.01308 to 0.01307, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7507
#
# Epoch 00021: CRPS_score_val improved from 0.01307 to 0.01304, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7463
#
# Epoch 00022: CRPS_score_val improved from 0.01304 to 0.01304, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7378
#
# Epoch 00023: CRPS_score_val improved from 0.01304 to 0.01301, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.7307
#
# Epoch 00024: CRPS_score_val improved from 0.01301 to 0.01299, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7256
#
# Epoch 00025: CRPS_score_val improved from 0.01299 to 0.01299, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7218
#
# Epoch 00026: CRPS_score_val improved from 0.01299 to 0.01297, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7206
#
# Epoch 00027: CRPS_score_val did not improve from 0.01297
# Epoch 28/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7178
#
# Epoch 00028: CRPS_score_val improved from 0.01297 to 0.01295, saving model to best_model.h5
# Epoch 29/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7141
#
# Epoch 00029: CRPS_score_val improved from 0.01295 to 0.01293, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.7093
#
# Epoch 00030: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 31/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7035
#
# Epoch 00031: CRPS_score_val improved from 0.01292 to 0.01291, saving model to best_model.h5
# Epoch 32/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.7027
#
# Epoch 00032: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6937
#
# Epoch 00033: CRPS_score_val did not improve from 0.01290
# Epoch 34/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6938
#
# Epoch 00034: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6926
#
# Epoch 00035: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 36/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6859
#
# Epoch 00036: CRPS_score_val did not improve from 0.01289
# Epoch 37/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6851
#
# Epoch 00037: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.6875
#
# Epoch 00038: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 39/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6828
#
# Epoch 00039: CRPS_score_val did not improve from 0.01287
# Epoch 40/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6763
#
# Epoch 00040: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 41/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6770
#
# Epoch 00041: CRPS_score_val did not improve from 0.01286
# Epoch 42/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.6670
#
# Epoch 00042: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 43/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6681
#
# Epoch 00043: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 44/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6660
#
# Epoch 00044: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 45/100
# 18536/18536 [==============================] - 2s 86us/step - loss: 2.6657
#
# Epoch 00045: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 46/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6629
#
# Epoch 00046: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 47/100
# 18536/18536 [==============================] - 1s 81us/step - loss: 2.6598
#
# Epoch 00047: CRPS_score_val did not improve from 0.01283
# Epoch 48/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6506
#
# Epoch 00048: CRPS_score_val did not improve from 0.01283
# Epoch 49/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6544
#
# Epoch 00049: CRPS_score_val did not improve from 0.01283
# Epoch 50/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6519
#
# Epoch 00050: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 51/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6518
#
# Epoch 00051: CRPS_score_val did not improve from 0.01283
# Epoch 52/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6463
#
# Epoch 00052: CRPS_score_val did not improve from 0.01283
# Epoch 53/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6414
#
# Epoch 00053: CRPS_score_val did not improve from 0.01283
# Epoch 54/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6455
#
# Epoch 00054: CRPS_score_val did not improve from 0.01283
# Epoch 55/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6450
#
# Epoch 00055: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 56/100
# 18536/18536 [==============================] - 2s 81us/step - loss: 2.6364
#
# Epoch 00056: CRPS_score_val did not improve from 0.01282
# Epoch 57/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6368
#
# Epoch 00057: CRPS_score_val did not improve from 0.01282
# Epoch 58/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6331
#
# Epoch 00058: CRPS_score_val did not improve from 0.01282
# Epoch 59/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6276
#
# Epoch 00059: CRPS_score_val improved from 0.01282 to 0.01282, saving model to best_model.h5
# Epoch 60/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6271
#
# Epoch 00060: CRPS_score_val did not improve from 0.01282
# Epoch 61/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6278
#
# Epoch 00061: CRPS_score_val did not improve from 0.01282
# Epoch 62/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6244
#
# Epoch 00062: CRPS_score_val did not improve from 0.01282
# Epoch 63/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6207
#
# Epoch 00063: CRPS_score_val did not improve from 0.01282
# Epoch 64/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6175
#
# Epoch 00064: CRPS_score_val did not improve from 0.01282
# Epoch 65/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6155
#
# Epoch 00065: CRPS_score_val did not improve from 0.01282
# Epoch 66/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6163
#
# Epoch 00066: CRPS_score_val did not improve from 0.01282
# Epoch 67/100
# 18536/18536 [==============================] - 1s 79us/step - loss: 2.6135
#
# Epoch 00067: CRPS_score_val did not improve from 0.01282
# Epoch 68/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6087
#
# Epoch 00068: CRPS_score_val did not improve from 0.01282
# Epoch 69/100
# 18536/18536 [==============================] - 1s 80us/step - loss: 2.6086
# Restoring model weights from the end of the best epoch
#
# Epoch 00069: CRPS_score_val did not improve from 0.01282
# Epoch 00069: early stopping
# the 1 fold crps is 0.012819
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 120us/step - loss: 5.5797
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08223, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 5.0995
#
# Epoch 00002: CRPS_score_val improved from 0.08223 to 0.07831, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.6740
#
# Epoch 00003: CRPS_score_val improved from 0.07831 to 0.06432, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.2875
#
# Epoch 00004: CRPS_score_val improved from 0.06432 to 0.04355, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.8969
#
# Epoch 00005: CRPS_score_val improved from 0.04355 to 0.02658, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.5684
#
# Epoch 00006: CRPS_score_val improved from 0.02658 to 0.01863, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.3175
#
# Epoch 00007: CRPS_score_val improved from 0.01863 to 0.01557, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.1253
#
# Epoch 00008: CRPS_score_val improved from 0.01557 to 0.01417, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.0052
#
# Epoch 00009: CRPS_score_val improved from 0.01417 to 0.01366, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9409
#
# Epoch 00010: CRPS_score_val improved from 0.01366 to 0.01343, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8763
#
# Epoch 00011: CRPS_score_val improved from 0.01343 to 0.01333, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8599
#
# Epoch 00012: CRPS_score_val improved from 0.01333 to 0.01325, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8386
#
# Epoch 00013: CRPS_score_val improved from 0.01325 to 0.01322, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.8148
#
# Epoch 00014: CRPS_score_val improved from 0.01322 to 0.01316, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8033
#
# Epoch 00015: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7877
#
# Epoch 00016: CRPS_score_val improved from 0.01312 to 0.01310, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7755
#
# Epoch 00017: CRPS_score_val improved from 0.01310 to 0.01305, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7677
#
# Epoch 00018: CRPS_score_val improved from 0.01305 to 0.01303, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7490
#
# Epoch 00019: CRPS_score_val improved from 0.01303 to 0.01299, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7526
#
# Epoch 00020: CRPS_score_val improved from 0.01299 to 0.01298, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7403
#
# Epoch 00021: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7405
#
# Epoch 00022: CRPS_score_val improved from 0.01296 to 0.01296, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7317
#
# Epoch 00023: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7248
#
# Epoch 00024: CRPS_score_val improved from 0.01293 to 0.01291, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7220
#
# Epoch 00025: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7152
#
# Epoch 00026: CRPS_score_val did not improve from 0.01290
# Epoch 27/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7108
#
# Epoch 00027: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7072
#
# Epoch 00028: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7020
#
# Epoch 00029: CRPS_score_val did not improve from 0.01288
# Epoch 30/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6983
#
# Epoch 00030: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6930
#
# Epoch 00031: CRPS_score_val improved from 0.01287 to 0.01287, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6940
#
# Epoch 00032: CRPS_score_val improved from 0.01287 to 0.01284, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6893
#
# Epoch 00033: CRPS_score_val did not improve from 0.01284
# Epoch 34/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6876
#
# Epoch 00034: CRPS_score_val did not improve from 0.01284
# Epoch 35/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6827
#
# Epoch 00035: CRPS_score_val did not improve from 0.01284
# Epoch 36/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6805
#
# Epoch 00036: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6824
#
# Epoch 00037: CRPS_score_val did not improve from 0.01284
# Epoch 38/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6808
#
# Epoch 00038: CRPS_score_val did not improve from 0.01284
# Epoch 39/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6766
#
# Epoch 00039: CRPS_score_val did not improve from 0.01284
# Epoch 40/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6688
#
# Epoch 00040: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6708
#
# Epoch 00041: CRPS_score_val improved from 0.01283 to 0.01283, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6701
#
# Epoch 00042: CRPS_score_val did not improve from 0.01283
# Epoch 43/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6670
#
# Epoch 00043: CRPS_score_val improved from 0.01283 to 0.01280, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6533
#
# Epoch 00044: CRPS_score_val did not improve from 0.01280
# Epoch 45/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6591
#
# Epoch 00045: CRPS_score_val did not improve from 0.01280
# Epoch 46/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6579
#
# Epoch 00046: CRPS_score_val did not improve from 0.01280
# Epoch 47/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6590
#
# Epoch 00047: CRPS_score_val did not improve from 0.01280
# Epoch 48/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6493
#
# Epoch 00048: CRPS_score_val did not improve from 0.01280
# Epoch 49/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6543
#
# Epoch 00049: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6494
#
# Epoch 00050: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6448
#
# Epoch 00051: CRPS_score_val did not improve from 0.01280
# Epoch 52/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6432
#
# Epoch 00052: CRPS_score_val did not improve from 0.01280
# Epoch 53/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6440
#
# Epoch 00053: CRPS_score_val did not improve from 0.01280
# Epoch 54/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6397
#
# Epoch 00054: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6327
#
# Epoch 00055: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6378
#
# Epoch 00056: CRPS_score_val did not improve from 0.01277
# Epoch 57/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6296
#
# Epoch 00057: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6333
#
# Epoch 00058: CRPS_score_val did not improve from 0.01277
# Epoch 59/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6269
#
# Epoch 00059: CRPS_score_val did not improve from 0.01277
# Epoch 60/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6287
#
# Epoch 00060: CRPS_score_val did not improve from 0.01277
# Epoch 61/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6209
#
# Epoch 00061: CRPS_score_val did not improve from 0.01277
# Epoch 62/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6183
#
# Epoch 00062: CRPS_score_val did not improve from 0.01277
# Epoch 63/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6172
#
# Epoch 00063: CRPS_score_val did not improve from 0.01277
# Epoch 64/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6160
#
# Epoch 00064: CRPS_score_val did not improve from 0.01277
# Epoch 65/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6142
#
# Epoch 00065: CRPS_score_val did not improve from 0.01277
# Epoch 66/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6108
#
# Epoch 00066: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 67/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6087
#
# Epoch 00067: CRPS_score_val did not improve from 0.01276
# Epoch 68/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6075
#
# Epoch 00068: CRPS_score_val did not improve from 0.01276
# Epoch 69/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6016
#
# Epoch 00069: CRPS_score_val did not improve from 0.01276
# Epoch 70/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5999
#
# Epoch 00070: CRPS_score_val did not improve from 0.01276
# Epoch 71/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5898
#
# Epoch 00071: CRPS_score_val did not improve from 0.01276
# Epoch 72/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.5969
#
# Epoch 00072: CRPS_score_val did not improve from 0.01276
# Epoch 73/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5959
#
# Epoch 00073: CRPS_score_val did not improve from 0.01276
# Epoch 74/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5901
#
# Epoch 00074: CRPS_score_val did not improve from 0.01276
# Epoch 75/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5959
#
# Epoch 00075: CRPS_score_val did not improve from 0.01276
# Epoch 76/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.5829
# Restoring model weights from the end of the best epoch
#
# Epoch 00076: CRPS_score_val did not improve from 0.01276
# Epoch 00076: early stopping
# the 2 fold crps is 0.012755
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.6082
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08285, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 5.1543
#
# Epoch 00002: CRPS_score_val improved from 0.08285 to 0.07868, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 78us/step - loss: 4.7508
#
# Epoch 00003: CRPS_score_val improved from 0.07868 to 0.06565, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.3525
#
# Epoch 00004: CRPS_score_val improved from 0.06565 to 0.04546, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.9428
#
# Epoch 00005: CRPS_score_val improved from 0.04546 to 0.02754, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 3.5904
#
# Epoch 00006: CRPS_score_val improved from 0.02754 to 0.01929, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.3003
#
# Epoch 00007: CRPS_score_val improved from 0.01929 to 0.01550, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.1218
#
# Epoch 00008: CRPS_score_val improved from 0.01550 to 0.01397, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9912
#
# Epoch 00009: CRPS_score_val improved from 0.01397 to 0.01354, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9374
#
# Epoch 00010: CRPS_score_val improved from 0.01354 to 0.01330, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8867
#
# Epoch 00011: CRPS_score_val improved from 0.01330 to 0.01319, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8600
#
# Epoch 00012: CRPS_score_val improved from 0.01319 to 0.01313, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8330
#
# Epoch 00013: CRPS_score_val improved from 0.01313 to 0.01307, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.8157
#
# Epoch 00014: CRPS_score_val improved from 0.01307 to 0.01302, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7956
#
# Epoch 00015: CRPS_score_val improved from 0.01302 to 0.01299, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7934
#
# Epoch 00016: CRPS_score_val improved from 0.01299 to 0.01297, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7768
#
# Epoch 00017: CRPS_score_val improved from 0.01297 to 0.01293, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7623
#
# Epoch 00018: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7586
#
# Epoch 00019: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7500
#
# Epoch 00020: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7434
#
# Epoch 00021: CRPS_score_val improved from 0.01288 to 0.01285, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7429
#
# Epoch 00022: CRPS_score_val improved from 0.01285 to 0.01282, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7318
#
# Epoch 00023: CRPS_score_val improved from 0.01282 to 0.01281, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7249
#
# Epoch 00024: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7210
#
# Epoch 00025: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7119
#
# Epoch 00026: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7135
#
# Epoch 00027: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7097
#
# Epoch 00028: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7052
#
# Epoch 00029: CRPS_score_val did not improve from 0.01277
# Epoch 30/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6985
#
# Epoch 00030: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6989
#
# Epoch 00031: CRPS_score_val did not improve from 0.01277
# Epoch 32/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6933
#
# Epoch 00032: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6892
#
# Epoch 00033: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6939
#
# Epoch 00034: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6891
#
# Epoch 00035: CRPS_score_val did not improve from 0.01275
# Epoch 36/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6846
#
# Epoch 00036: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6805
#
# Epoch 00037: CRPS_score_val did not improve from 0.01274
# Epoch 38/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6799
#
# Epoch 00038: CRPS_score_val did not improve from 0.01274
# Epoch 39/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6793
#
# Epoch 00039: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6777
#
# Epoch 00040: CRPS_score_val did not improve from 0.01273
# Epoch 41/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6701
#
# Epoch 00041: CRPS_score_val did not improve from 0.01273
# Epoch 42/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6659
#
# Epoch 00042: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6633
#
# Epoch 00043: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6670
#
# Epoch 00044: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6585
#
# Epoch 00045: CRPS_score_val did not improve from 0.01270
# Epoch 46/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6625
#
# Epoch 00046: CRPS_score_val did not improve from 0.01270
# Epoch 47/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6570
#
# Epoch 00047: CRPS_score_val did not improve from 0.01270
# Epoch 48/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6550
#
# Epoch 00048: CRPS_score_val did not improve from 0.01270
# Epoch 49/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6520
#
# Epoch 00049: CRPS_score_val did not improve from 0.01270
# Epoch 50/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6514
#
# Epoch 00050: CRPS_score_val did not improve from 0.01270
# Epoch 51/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6446
#
# Epoch 00051: CRPS_score_val did not improve from 0.01270
# Epoch 52/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6477
#
# Epoch 00052: CRPS_score_val did not improve from 0.01270
# Epoch 53/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6448
#
# Epoch 00053: CRPS_score_val did not improve from 0.01270
# Epoch 54/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6354
# Restoring model weights from the end of the best epoch
#
# Epoch 00054: CRPS_score_val did not improve from 0.01270
# Epoch 00054: early stopping
# the 3 fold crps is 0.012700
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 127us/step - loss: 5.5890
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08253, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 5.1293
#
# Epoch 00002: CRPS_score_val improved from 0.08253 to 0.07781, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.7173
#
# Epoch 00003: CRPS_score_val improved from 0.07781 to 0.06532, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.3029
#
# Epoch 00004: CRPS_score_val improved from 0.06532 to 0.04601, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.9311
#
# Epoch 00005: CRPS_score_val improved from 0.04601 to 0.02909, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.5727
#
# Epoch 00006: CRPS_score_val improved from 0.02909 to 0.02066, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.2963
#
# Epoch 00007: CRPS_score_val improved from 0.02066 to 0.01653, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 3.0968
#
# Epoch 00008: CRPS_score_val improved from 0.01653 to 0.01436, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9987
#
# Epoch 00009: CRPS_score_val improved from 0.01436 to 0.01357, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.9201
#
# Epoch 00010: CRPS_score_val improved from 0.01357 to 0.01336, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8887
#
# Epoch 00011: CRPS_score_val improved from 0.01336 to 0.01319, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.8534
#
# Epoch 00012: CRPS_score_val improved from 0.01319 to 0.01311, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8434
#
# Epoch 00013: CRPS_score_val improved from 0.01311 to 0.01305, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.8155
#
# Epoch 00014: CRPS_score_val improved from 0.01305 to 0.01301, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7964
#
# Epoch 00015: CRPS_score_val improved from 0.01301 to 0.01297, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7860
#
# Epoch 00016: CRPS_score_val improved from 0.01297 to 0.01292, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7798
#
# Epoch 00017: CRPS_score_val improved from 0.01292 to 0.01290, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7627
#
# Epoch 00018: CRPS_score_val improved from 0.01290 to 0.01286, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7584
#
# Epoch 00019: CRPS_score_val improved from 0.01286 to 0.01283, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7444
#
# Epoch 00020: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7389
#
# Epoch 00021: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7393
#
# Epoch 00022: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7310
#
# Epoch 00023: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7265
#
# Epoch 00024: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7189
#
# Epoch 00025: CRPS_score_val improved from 0.01277 to 0.01274, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.7162
#
# Epoch 00026: CRPS_score_val improved from 0.01274 to 0.01271, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.7095
#
# Epoch 00027: CRPS_score_val did not improve from 0.01271
# Epoch 28/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7133
#
# Epoch 00028: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6994
#
# Epoch 00029: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6987
#
# Epoch 00030: CRPS_score_val did not improve from 0.01270
# Epoch 31/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6927
#
# Epoch 00031: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6942
#
# Epoch 00032: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6921
#
# Epoch 00033: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6932
#
# Epoch 00034: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6843
#
# Epoch 00035: CRPS_score_val did not improve from 0.01267
# Epoch 36/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6857
#
# Epoch 00036: CRPS_score_val did not improve from 0.01267
# Epoch 37/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6815
#
# Epoch 00037: CRPS_score_val did not improve from 0.01267
# Epoch 38/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6797
#
# Epoch 00038: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6777
#
# Epoch 00039: CRPS_score_val did not improve from 0.01267
# Epoch 40/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6730
#
# Epoch 00040: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6761
#
# Epoch 00041: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6631
#
# Epoch 00042: CRPS_score_val did not improve from 0.01266
# Epoch 43/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6677
#
# Epoch 00043: CRPS_score_val did not improve from 0.01266
# Epoch 44/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6646
#
# Epoch 00044: CRPS_score_val did not improve from 0.01266
# Epoch 45/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6638
#
# Epoch 00045: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6605
#
# Epoch 00046: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6503
#
# Epoch 00047: CRPS_score_val did not improve from 0.01265
# Epoch 48/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6521
#
# Epoch 00048: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6540
#
# Epoch 00049: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6529
#
# Epoch 00050: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6463
#
# Epoch 00051: CRPS_score_val improved from 0.01264 to 0.01263, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6459
#
# Epoch 00052: CRPS_score_val did not improve from 0.01263
# Epoch 53/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6430
#
# Epoch 00053: CRPS_score_val did not improve from 0.01263
# Epoch 54/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6344
#
# Epoch 00054: CRPS_score_val did not improve from 0.01263
# Epoch 55/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6371
#
# Epoch 00055: CRPS_score_val did not improve from 0.01263
# Epoch 56/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6341
#
# Epoch 00056: CRPS_score_val did not improve from 0.01263
# Epoch 57/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6325
#
# Epoch 00057: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6276
#
# Epoch 00058: CRPS_score_val did not improve from 0.01263
# Epoch 59/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6251
#
# Epoch 00059: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 60/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6273
#
# Epoch 00060: CRPS_score_val did not improve from 0.01263
# Epoch 61/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6275
#
# Epoch 00061: CRPS_score_val improved from 0.01263 to 0.01263, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6208
#
# Epoch 00062: CRPS_score_val improved from 0.01263 to 0.01262, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6205
#
# Epoch 00063: CRPS_score_val did not improve from 0.01262
# Epoch 64/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6149
#
# Epoch 00064: CRPS_score_val did not improve from 0.01262
# Epoch 65/100
# 18537/18537 [==============================] - 3s 140us/step - loss: 2.6129
#
# Epoch 00065: CRPS_score_val did not improve from 0.01262
# Epoch 66/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6150
#
# Epoch 00066: CRPS_score_val did not improve from 0.01262
# Epoch 67/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6134
#
# Epoch 00067: CRPS_score_val did not improve from 0.01262
# Epoch 68/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6083
#
# Epoch 00068: CRPS_score_val did not improve from 0.01262
# Epoch 69/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 2.6041
#
# Epoch 00069: CRPS_score_val improved from 0.01262 to 0.01262, saving model to best_model.h5
# Epoch 70/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5977
#
# Epoch 00070: CRPS_score_val improved from 0.01262 to 0.01262, saving model to best_model.h5
# Epoch 71/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5973
#
# Epoch 00071: CRPS_score_val did not improve from 0.01262
# Epoch 72/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.5951
#
# Epoch 00072: CRPS_score_val did not improve from 0.01262
# Epoch 73/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.5986
#
# Epoch 00073: CRPS_score_val did not improve from 0.01262
# Epoch 74/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5910
#
# Epoch 00074: CRPS_score_val did not improve from 0.01262
# Epoch 75/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5924
#
# Epoch 00075: CRPS_score_val did not improve from 0.01262
# Epoch 76/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5884
#
# Epoch 00076: CRPS_score_val did not improve from 0.01262
# Epoch 77/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.5865
#
# Epoch 00077: CRPS_score_val did not improve from 0.01262
# Epoch 78/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5841
#
# Epoch 00078: CRPS_score_val did not improve from 0.01262
# Epoch 79/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5789
#
# Epoch 00079: CRPS_score_val did not improve from 0.01262
# Epoch 80/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.5810
# Restoring model weights from the end of the best epoch
#
# Epoch 00080: CRPS_score_val did not improve from 0.01262
# Epoch 00080: early stopping
# the 4 fold crps is 0.012616
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 131us/step - loss: 5.6008
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08281, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 1s 79us/step - loss: 5.1452
#
# Epoch 00002: CRPS_score_val improved from 0.08281 to 0.07826, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 4.7390
#
# Epoch 00003: CRPS_score_val improved from 0.07826 to 0.06503, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 4.3433
#
# Epoch 00004: CRPS_score_val improved from 0.06503 to 0.04555, saving model to best_model.h5
# Epoch 5/100
# ...
#
# Epoch 00047: CRPS_score_val did not improve from 0.01341
# Epoch 48/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6529
#
# Epoch 00048: CRPS_score_val improved from 0.01341 to 0.01340, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6491
#
# Epoch 00049: CRPS_score_val did not improve from 0.01340
# Epoch 50/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6511
#
# Epoch 00050: CRPS_score_val did not improve from 0.01340
# Epoch 51/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6471
#
# Epoch 00051: CRPS_score_val did not improve from 0.01340
# Epoch 52/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6449
#
# Epoch 00052: CRPS_score_val did not improve from 0.01340
# Epoch 53/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6424
#
# Epoch 00053: CRPS_score_val did not improve from 0.01340
# Epoch 54/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6385
#
# Epoch 00054: CRPS_score_val improved from 0.01340 to 0.01340, saving model to best_model.h5
# Epoch 55/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6367
#
# Epoch 00055: CRPS_score_val improved from 0.01340 to 0.01340, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6385
#
# Epoch 00056: CRPS_score_val improved from 0.01340 to 0.01339, saving model to best_model.h5
# Epoch 57/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6333
#
# Epoch 00057: CRPS_score_val improved from 0.01339 to 0.01338, saving model to best_model.h5
# Epoch 58/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6309
#
# Epoch 00058: CRPS_score_val did not improve from 0.01338
# Epoch 59/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6263
#
# Epoch 00059: CRPS_score_val did not improve from 0.01338
# Epoch 60/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6281
#
# Epoch 00060: CRPS_score_val did not improve from 0.01338
# Epoch 61/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6234
#
# Epoch 00061: CRPS_score_val did not improve from 0.01338
# Epoch 62/100
# 18537/18537 [==============================] - 2s 85us/step - loss: 2.6180
#
# Epoch 00062: CRPS_score_val improved from 0.01338 to 0.01338, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.6207
#
# Epoch 00063: CRPS_score_val improved from 0.01338 to 0.01338, saving model to best_model.h5
# Epoch 64/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6174
#
# Epoch 00064: CRPS_score_val did not improve from 0.01338
# Epoch 65/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6148
#
# Epoch 00065: CRPS_score_val did not improve from 0.01338
# Epoch 66/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.6125
#
# Epoch 00066: CRPS_score_val did not improve from 0.01338
# Epoch 67/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.6084
#
# Epoch 00067: CRPS_score_val did not improve from 0.01338
# Epoch 68/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6091
#
# Epoch 00068: CRPS_score_val improved from 0.01338 to 0.01336, saving model to best_model.h5
# Epoch 69/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6063
#
# Epoch 00069: CRPS_score_val did not improve from 0.01336
# Epoch 70/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6045
#
# Epoch 00070: CRPS_score_val did not improve from 0.01336
# Epoch 71/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.5943
#
# Epoch 00071: CRPS_score_val did not improve from 0.01336
# Epoch 72/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.5955
#
# Epoch 00072: CRPS_score_val did not improve from 0.01336
# Epoch 73/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.5928
#
# Epoch 00073: CRPS_score_val did not improve from 0.01336
# Epoch 74/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5936
#
# Epoch 00074: CRPS_score_val did not improve from 0.01336
# Epoch 75/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.5854
#
# Epoch 00075: CRPS_score_val did not improve from 0.01336
# Epoch 76/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5934
#
# Epoch 00076: CRPS_score_val did not improve from 0.01336
# Epoch 77/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.5840
#
# Epoch 00077: CRPS_score_val did not improve from 0.01336
# Epoch 78/100
# 18537/18537 [==============================] - 2s 86us/step - loss: 2.5801
# Restoring model weights from the end of the best epoch
#
# Epoch 00078: CRPS_score_val did not improve from 0.01336
# Epoch 00078: early stopping
# the 4 fold crps is 0.013364
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 160us/step - loss: 5.6017
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08238, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 5.1084
#
# Epoch 00002: CRPS_score_val improved from 0.08238 to 0.07772, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 4.6936
#
# Epoch 00003: CRPS_score_val improved from 0.07772 to 0.06341, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 4.3072
#
# Epoch 00004: CRPS_score_val improved from 0.06341 to 0.04239, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.9279
#
# Epoch 00005: CRPS_score_val improved from 0.04239 to 0.02601, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.5899
#
# Epoch 00006: CRPS_score_val improved from 0.02601 to 0.01804, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 3.3128
#
# Epoch 00007: CRPS_score_val improved from 0.01804 to 0.01518, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 3.1203
#
# Epoch 00008: CRPS_score_val improved from 0.01518 to 0.01398, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 3.0062
#
# Epoch 00009: CRPS_score_val improved from 0.01398 to 0.01351, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.9361
#
# Epoch 00010: CRPS_score_val improved from 0.01351 to 0.01326, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.8850
#
# Epoch 00011: CRPS_score_val improved from 0.01326 to 0.01318, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.8617
#
# Epoch 00012: CRPS_score_val improved from 0.01318 to 0.01313, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.8346
#
# Epoch 00013: CRPS_score_val improved from 0.01313 to 0.01308, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.8078
#
# Epoch 00014: CRPS_score_val improved from 0.01308 to 0.01303, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.8070
#
# Epoch 00015: CRPS_score_val improved from 0.01303 to 0.01299, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7893
#
# Epoch 00016: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7783
#
# Epoch 00017: CRPS_score_val improved from 0.01296 to 0.01292, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7687
#
# Epoch 00018: CRPS_score_val improved from 0.01292 to 0.01289, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7533
#
# Epoch 00019: CRPS_score_val improved from 0.01289 to 0.01287, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7536
#
# Epoch 00020: CRPS_score_val improved from 0.01287 to 0.01284, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 84us/step - loss: 2.7479
#
# Epoch 00021: CRPS_score_val improved from 0.01284 to 0.01282, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.7349
#
# Epoch 00022: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7287
#
# Epoch 00023: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.7322
#
# Epoch 00024: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7252
#
# Epoch 00025: CRPS_score_val improved from 0.01279 to 0.01276, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7176
#
# Epoch 00026: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.7166
#
# Epoch 00027: CRPS_score_val did not improve from 0.01275
# Epoch 28/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7064
#
# Epoch 00028: CRPS_score_val improved from 0.01275 to 0.01273, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7056
#
# Epoch 00029: CRPS_score_val did not improve from 0.01273
# Epoch 30/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7013
#
# Epoch 00030: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.7066
#
# Epoch 00031: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6968
#
# Epoch 00032: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6940
#
# Epoch 00033: CRPS_score_val did not improve from 0.01270
# Epoch 34/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6899
#
# Epoch 00034: CRPS_score_val did not improve from 0.01270
# Epoch 35/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6809
#
# Epoch 00035: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6827
#
# Epoch 00036: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6793
#
# Epoch 00037: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6826
#
# Epoch 00038: CRPS_score_val did not improve from 0.01268
# Epoch 39/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6741
#
# Epoch 00039: CRPS_score_val did not improve from 0.01268
# Epoch 40/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6751
#
# Epoch 00040: CRPS_score_val did not improve from 0.01268
# Epoch 41/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6732
#
# Epoch 00041: CRPS_score_val did not improve from 0.01268
# Epoch 42/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6752
#
# Epoch 00042: CRPS_score_val did not improve from 0.01268
# Epoch 43/100
# 18537/18537 [==============================] - 2s 83us/step - loss: 2.6635
#
# Epoch 00043: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6634
#
# Epoch 00044: CRPS_score_val did not improve from 0.01267
# Epoch 45/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6599
#
# Epoch 00045: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6577
#
# Epoch 00046: CRPS_score_val did not improve from 0.01267
# Epoch 47/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6597
#
# Epoch 00047: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 48/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6570
#
# Epoch 00048: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 49/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6582
#
# Epoch 00049: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6476
#
# Epoch 00050: CRPS_score_val did not improve from 0.01265
# Epoch 51/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6486
#
# Epoch 00051: CRPS_score_val did not improve from 0.01265
# Epoch 52/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6465
#
# Epoch 00052: CRPS_score_val did not improve from 0.01265
# Epoch 53/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6447
#
# Epoch 00053: CRPS_score_val did not improve from 0.01265
# Epoch 54/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6434
#
# Epoch 00054: CRPS_score_val did not improve from 0.01265
# Epoch 55/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6349
#
# Epoch 00055: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6355
#
# Epoch 00056: CRPS_score_val did not improve from 0.01264
# Epoch 57/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6296
#
# Epoch 00057: CRPS_score_val did not improve from 0.01264
# Epoch 58/100
# 18537/18537 [==============================] - 1s 81us/step - loss: 2.6332
#
# Epoch 00058: CRPS_score_val did not improve from 0.01264
# Epoch 59/100
# 18537/18537 [==============================] - 2s 82us/step - loss: 2.6330
#
# Epoch 00059: CRPS_score_val did not improve from 0.01264
# Epoch 60/100
# 18537/18537 [==============================] - 2s 81us/step - loss: 2.6327
#
# Epoch 00060: CRPS_score_val did not improve from 0.01264
# Epoch 61/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6256
#
# Epoch 00061: CRPS_score_val did not improve from 0.01264
# Epoch 62/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6223
#
# Epoch 00062: CRPS_score_val did not improve from 0.01264
# Epoch 63/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6226
#
# Epoch 00063: CRPS_score_val did not improve from 0.01264
# Epoch 64/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6129
#
# Epoch 00064: CRPS_score_val did not improve from 0.01264
# Epoch 65/100
# 18537/18537 [==============================] - 1s 80us/step - loss: 2.6162
# Restoring model weights from the end of the best epoch
#
# Epoch 00065: CRPS_score_val did not improve from 0.01264
# Epoch 00065: early stopping
# the 5 fold crps is 0.012645
# mean crps is 0.012794

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012794

# %% [markdown]
# # Time for the actual submission

# %%
# %%time
if  TRAIN_OFFLINE==False:
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()

    for (test_df, sample_prediction_df) in iter_test:
        basetable = create_features(test_df, deploy=True)
        basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        env.predict(preds_df)

    env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 12min 4s, sys: 19.6 s, total: 12min 23s
# Wall time: 11min 41s
