# %% [markdown]
# Model is from https://www.kaggle.com/bestpredict/location-eda-8eb410
# Rusher features idea is from the discussion:
# https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/113698#latest-675738

# %%
import os
# os.environ['CUDA_VISIBLE_DEVICES'] = "1"


import numpy as np
import pandas as pd
import sklearn.metrics as mtr
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda,BatchNormalization
from keras.models import Model
import keras.backend as K
from keras.callbacks import Callback
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import datetime

TRAIN_OFFLINE = False


pd.set_option('display.max_columns', 50)
pd.set_option('display.max_rows', 150)
# Out:
# Using TensorFlow backend.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nfl-big-data-bowl-2020/train.csv
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/test.csv.encrypted
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/competition.cpython-36m-x86_64-linux-gnu.so
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/__init__.py
# /kaggle/input/nfl-big-data-bowl-2020/kaggle/competitions/nflrush/sample_submission.csv.encrypted

# %%
# train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})
if TRAIN_OFFLINE:
    train = pd.read_csv('../input/train.csv', dtype={'WindSpeed': 'object'})
else:
    train = pd.read_csv('/kaggle/input/nfl-big-data-bowl-2020/train.csv', dtype={'WindSpeed': 'object'})

# %%
outcomes = train[['GameId','PlayId','Yards']].drop_duplicates()

# %%
def strtoseconds(txt):
    txt = txt.split(':')
    ans = int(txt[0])*60 + int(txt[1]) + int(txt[2])/60
    return ans

def strtofloat(x):
    try:
        return float(x)
    except:
        return -1

def map_weather(txt):
    ans = 1
    if pd.isna(txt):
        return 0
    if 'partly' in txt:
        ans*=0.5
    if 'climate controlled' in txt or 'indoor' in txt:
        return ans*3
    if 'sunny' in txt or 'sun' in txt:
        return ans*2
    if 'clear' in txt:
        return ans
    if 'cloudy' in txt:
        return -ans
    if 'rain' in txt or 'rainy' in txt:
        return -2*ans
    if 'snow' in txt:
        return -3*ans
    return 0

def OffensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0, 'QB' : 0, 'RB' : 0, 'TE' : 0, 'WR' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def DefensePersonnelSplit(x):
    dic = {'DB' : 0, 'DL' : 0, 'LB' : 0, 'OL' : 0}
    for xx in x.split(","):
        xxs = xx.split(" ")
        dic[xxs[-1]] = int(xxs[-2])
    return dic

def orientation_to_cat(x):
    x = np.clip(x, 0, 360 - 1)
    try:
        return str(int(x/15))
    except:
        return "nan"
def preprocess(train):
    ## GameClock
    train['GameClock_sec'] = train['GameClock'].apply(strtoseconds)
    train["GameClock_minute"] = train["GameClock"].apply(lambda x : x.split(":")[0]).astype("object")

    ## Height
    train['PlayerHeight_dense'] = train['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))

    ## Time
    train['TimeHandoff'] = train['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
    train['TimeSnap'] = train['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

    train['TimeDelta'] = train.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
    train['PlayerBirthDate'] = train['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

    ## Age
    seconds_in_year = 60*60*24*365.25
    train['PlayerAge'] = train.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
    train["PlayerAge_ob"] = train['PlayerAge'].astype(np.int).astype("object")

    ## WindSpeed
    train['WindSpeed_ob'] = train['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
    train['WindSpeed_ob'] = train['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
    train['WindSpeed_dense'] = train['WindSpeed_ob'].apply(strtofloat)

    ## Weather
    train['GameWeather_process'] = train['GameWeather'].str.lower()
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: "indoor" if not pd.isna(x) and "indoor" in x else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('coudy', 'cloudy').replace('clouidy', 'cloudy').replace('party', 'partly') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('clear and sunny', 'sunny and clear') if not pd.isna(x) else x)
    train['GameWeather_process'] = train['GameWeather_process'].apply(lambda x: x.replace('skies', '').replace("mostly", "").strip() if not pd.isna(x) else x)
    train['GameWeather_dense'] = train['GameWeather_process'].apply(map_weather)

    ## Rusher
    train['IsRusher'] = (train['NflId'] == train['NflIdRusher'])
    train['IsRusher_ob'] = (train['NflId'] == train['NflIdRusher']).astype("object")
    temp = train[train["IsRusher"]][["Team", "PlayId"]].rename(columns={"Team":"RusherTeam"})
    train = train.merge(temp, on = "PlayId")
    train["IsRusherTeam"] = train["Team"] == train["RusherTeam"]

    ## dense -> categorical
    train["Quarter_ob"] = train["Quarter"].astype("object")
    train["Down_ob"] = train["Down"].astype("object")
    train["JerseyNumber_ob"] = train["JerseyNumber"].astype("object")
    train["YardLine_ob"] = train["YardLine"].astype("object")
  


    ## Orientation and Dir
    train["Orientation_ob"] = train["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
    train["Dir_ob"] = train["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

    train["Orientation_sin"] = train["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Orientation_cos"] = train["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
    train["Dir_sin"] = train["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
    train["Dir_cos"] = train["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))

    ## diff Score
    train["diffScoreBeforePlay"] = train["HomeScoreBeforePlay"] - train["VisitorScoreBeforePlay"]
    train["diffScoreBeforePlay_binary_ob"] = (train["HomeScoreBeforePlay"] > train["VisitorScoreBeforePlay"]).astype("object")

    ## Turf
    Turf = {'Field Turf':'Artificial', 'A-Turf Titan':'Artificial', 'Grass':'Natural', 'UBU Sports Speed S5-M':'Artificial', 'Artificial':'Artificial', 'DD GrassMaster':'Artificial', 'Natural Grass':'Natural', 'UBU Speed Series-S5-M':'Artificial', 'FieldTurf':'Artificial', 'FieldTurf 360':'Artificial', 'Natural grass':'Natural', 'grass':'Natural', 'Natural':'Natural', 'Artifical':'Artificial', 'FieldTurf360':'Artificial', 'Naturall Grass':'Natural', 'Field turf':'Artificial', 'SISGrass':'Artificial', 'Twenty-Four/Seven Turf':'Artificial', 'natural grass':'Natural'} 
    train['Turf'] = train['Turf'].map(Turf)

    ## OffensePersonnel
    temp = train["OffensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(OffensePersonnelSplit(x)))
    temp.columns = ["Offense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## DefensePersonnel
    temp = train["DefensePersonnel"].iloc[np.arange(0, len(train), 22)].apply(lambda x : pd.Series(DefensePersonnelSplit(x)))
    temp.columns = ["Defense" + c for c in temp.columns]
    temp["PlayId"] = train["PlayId"].iloc[np.arange(0, len(train), 22)]
    train = train.merge(temp, on = "PlayId")

    ## sort
#     train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'Team', 'IsRusher']).reset_index(drop = True)
    train = train.sort_values(by = ['X']).sort_values(by = ['Dis']).sort_values(by=['PlayId', 'IsRusherTeam', 'IsRusher']).reset_index(drop = True)
    return train

# %% [markdown]
# ## Functions for anchoring offense moving left from {0,0}

# %%
def create_features(df, deploy=False):
    def new_X(x_coordinate, play_direction):
        if play_direction == 'left':
            return 120.0 - x_coordinate
        else:
            return x_coordinate

    def new_line(rush_team, field_position, yardline):
        if rush_team == field_position:
            # offense starting at X = 0 plus the 10 yard endzone plus the line of scrimmage
            return 10.0 + yardline
        else:
            # half the field plus the yards between midfield and the line of scrimmage
            return 60.0 + (50 - yardline)

    def new_orientation(angle, play_direction):
        if play_direction == 'left':
            new_angle = 360.0 - angle
            if new_angle == 360.0:
                new_angle = 0.0
            return new_angle
        else:
            return angle

    def euclidean_distance(x1,y1,x2,y2):
        x_diff = (x1-x2)**2
        y_diff = (y1-y2)**2

        return np.sqrt(x_diff + y_diff)

    def back_direction(orientation):
        if orientation > 180.0:
            return 1
        else:
            return 0

    def update_yardline(df):
        new_yardline = df[df['NflId'] == df['NflIdRusher']]
        new_yardline['YardLine'] = new_yardline[['PossessionTeam','FieldPosition','YardLine']].apply(lambda x: new_line(x[0],x[1],x[2]), axis=1)
        new_yardline = new_yardline[['GameId','PlayId','YardLine']]

        return new_yardline

    def update_orientation(df, yardline):
        df['X'] = df[['X','PlayDirection']].apply(lambda x: new_X(x[0],x[1]), axis=1)
        df['Orientation'] = df[['Orientation','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)
        df['Dir'] = df[['Dir','PlayDirection']].apply(lambda x: new_orientation(x[0],x[1]), axis=1)

        df = df.drop('YardLine', axis=1)
        df = pd.merge(df, yardline, on=['GameId','PlayId'], how='inner')

        return df

    def back_features(df):
        carriers = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','NflIdRusher','X','Y','Orientation','Dir','YardLine']]
        carriers['back_from_scrimmage'] = carriers['YardLine'] - carriers['X']
        carriers['back_oriented_down_field'] = carriers['Orientation'].apply(lambda x: back_direction(x))
        carriers['back_moving_down_field'] = carriers['Dir'].apply(lambda x: back_direction(x))
        carriers = carriers.rename(columns={'X':'back_X',
                                            'Y':'back_Y'})
        carriers = carriers[['GameId','PlayId','NflIdRusher','back_X','back_Y','back_from_scrimmage','back_oriented_down_field','back_moving_down_field']]

        return carriers

    def features_relative_to_back(df, carriers):
        player_distance = df[['GameId','PlayId','NflId','X','Y']]
        player_distance = pd.merge(player_distance, carriers, on=['GameId','PlayId'], how='inner')
        player_distance = player_distance[player_distance['NflId'] != player_distance['NflIdRusher']]
        player_distance['dist_to_back'] = player_distance[['X','Y','back_X','back_Y']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        player_distance = player_distance.groupby(['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field'])\
                                         .agg({'dist_to_back':['min','max','mean','std']})\
                                         .reset_index()
        player_distance.columns = ['GameId','PlayId','back_from_scrimmage','back_oriented_down_field','back_moving_down_field',
                                   'min_dist','max_dist','mean_dist','std_dist']

        return player_distance

    def defense_features(df):
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Team','X','Y']]
        rusher.columns = ['GameId','PlayId','RusherTeam','RusherX','RusherY']

        defense = pd.merge(df,rusher,on=['GameId','PlayId'],how='inner')
        defense = defense[defense['Team'] != defense['RusherTeam']][['GameId','PlayId','X','Y','RusherX','RusherY']]
        defense['def_dist_to_back'] = defense[['X','Y','RusherX','RusherY']].apply(lambda x: euclidean_distance(x[0],x[1],x[2],x[3]), axis=1)

        defense = defense.groupby(['GameId','PlayId'])\
                         .agg({'def_dist_to_back':['min','max','mean','std']})\
                         .reset_index()
        defense.columns = ['GameId','PlayId','def_min_dist','def_max_dist','def_mean_dist','def_std_dist']

        return defense
    
    def rusher_features(df):
        
        rusher = df[df['NflId'] == df['NflIdRusher']][['GameId','PlayId','Dir', 'S', 'A', 'X', 'Y']]
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS', 'RusherA', 'RusherX', 'RusherY']
        
       
        radian_angle = (90 - rusher['RusherDir']) * np.pi / 180.0
        v_horizontal = np.abs(rusher['RusherS'] * np.cos(radian_angle))
        v_vertical = np.abs(rusher['RusherS'] * np.sin(radian_angle)) 
        
       
        rusher['v_horizontal'] = v_horizontal
        rusher['v_vertical'] = v_vertical
        
        
        rusher.columns = ['GameId','PlayId', 'RusherDir', 'RusherS','RusherA','RusherX', 'RusherY','v_horizontal', 'v_vertical']
        
        
        return rusher

    def static_features(df):
        
        
        add_new_feas = []

        ## Height
        df['PlayerHeight_dense'] = df['PlayerHeight'].apply(lambda x: 12*int(x.split('-')[0])+int(x.split('-')[1]))
        
        add_new_feas.append('PlayerHeight_dense')

        ## Time
        df['TimeHandoff'] = df['TimeHandoff'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))
        df['TimeSnap'] = df['TimeSnap'].apply(lambda x: datetime.datetime.strptime(x, "%Y-%m-%dT%H:%M:%S.%fZ"))

        df['TimeDelta'] = df.apply(lambda row: (row['TimeHandoff'] - row['TimeSnap']).total_seconds(), axis=1)
        df['PlayerBirthDate'] =df['PlayerBirthDate'].apply(lambda x: datetime.datetime.strptime(x, "%m/%d/%Y"))

        ## Age
        seconds_in_year = 60*60*24*365.25
        df['PlayerAge'] = df.apply(lambda row: (row['TimeHandoff']-row['PlayerBirthDate']).total_seconds()/seconds_in_year, axis=1)
        add_new_feas.append('PlayerAge')

        ## WindSpeed
        df['WindSpeed_ob'] = df['WindSpeed'].apply(lambda x: x.lower().replace('mph', '').strip() if not pd.isna(x) else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split('-')[0])+int(x.split('-')[1]))/2 if not pd.isna(x) and '-' in x else x)
        df['WindSpeed_ob'] = df['WindSpeed_ob'].apply(lambda x: (int(x.split()[0])+int(x.split()[-1]))/2 if not pd.isna(x) and type(x)!=float and 'gusts up to' in x else x)
        df['WindSpeed_dense'] = df['WindSpeed_ob'].apply(strtofloat)
        add_new_feas.append('WindSpeed_dense')

        ## Orientation and Dir
        df["Orientation_ob"] = df["Orientation"].apply(lambda x : orientation_to_cat(x)).astype("object")
        df["Dir_ob"] = df["Dir"].apply(lambda x : orientation_to_cat(x)).astype("object")

        df["Orientation_sin"] = df["Orientation"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Orientation_cos"] = df["Orientation"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        df["Dir_sin"] = df["Dir"].apply(lambda x : np.sin(x/360 * 2 * np.pi))
        df["Dir_cos"] = df["Dir"].apply(lambda x : np.cos(x/360 * 2 * np.pi))
        add_new_feas.append("Dir_sin")
        add_new_feas.append("Dir_cos")

        ## diff Score
        df["diffScoreBeforePlay"] = df["HomeScoreBeforePlay"] - df["VisitorScoreBeforePlay"]
        add_new_feas.append("diffScoreBeforePlay")
    
    
        static_features = df[df['NflId'] == df['NflIdRusher']][add_new_feas+['GameId','PlayId','X','Y','S','A','Dis','Orientation','Dir',
                                                            'YardLine','Quarter','Down','Distance','DefendersInTheBox']].drop_duplicates()

        static_features.fillna(-999,inplace=True)
       

        return static_features


    def combine_features(relative_to_back, defense,rushing, static, deploy=deploy):
        df = pd.merge(relative_to_back,defense,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,rushing,on=['GameId','PlayId'],how='inner')
        df = pd.merge(df,static,on=['GameId','PlayId'],how='inner')

        if not deploy:
            df = pd.merge(df, outcomes, on=['GameId','PlayId'], how='inner')

        return df
    
    yardline = update_yardline(df)
    df = update_orientation(df, yardline)
    back_feats = back_features(df)
    rel_back = features_relative_to_back(df, back_feats)
    def_feats = defense_features(df)
    rush_feats = rusher_features(df)
    static_feats = static_features(df)
    basetable = combine_features(rel_back, def_feats,rush_feats,static_feats, deploy=deploy)
    
    return basetable

# %%
# %time train_basetable = create_features(train, False)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 5min 33s, sys: 5.92 s, total: 5min 39s
# Wall time: 5min 39s

# %% [markdown]
# # Let's split our data into train/val

# %%
X = train_basetable.copy()
yards = X.Yards

y = np.zeros((yards.shape[0], 199))
for idx, target in enumerate(list(yards)):
    y[idx][99 + target] = 1

X.drop(['GameId','PlayId','Yards'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.15, random_state=12345)

# %%
print(X_train.shape, X_val.shape)
print(y_train.shape, y_val.shape)
# Out:
# (19695, 36) (3476, 36)
# (19695, 199) (3476, 199)

# %% [markdown]
# # Let's build NN

# %% [markdown]
# Below class Metric based entirely on: https://www.kaggle.com/kingychiu/keras-nn-starter-crps-early-stopping
# <br></br>
# Below early stopping entirely based on: https://www.kaggle.com/c/nfl-big-data-bowl-2020/discussion/112868#latest-656533

# %%
from keras.layers import Dense,Input,Flatten,concatenate,Dropout,Lambda
from keras.models import Model
import keras.backend as K
import re
from keras.losses import binary_crossentropy
from  keras.callbacks import EarlyStopping,ModelCheckpoint
import codecs

from keras.utils import to_categorical
from keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from sklearn.metrics import f1_score




class CRPSCallback(Callback):
    
    def __init__(self,validation, predict_batch_size=20, include_on_batch=False):
        super(CRPSCallback, self).__init__()
        self.validation = validation
        self.predict_batch_size = predict_batch_size
        self.include_on_batch = include_on_batch
        
        print('validation shape',len(self.validation))

    def on_batch_begin(self, batch, logs={}):
        pass

    def on_train_begin(self, logs={}):
        if not ('CRPS_score_val' in self.params['metrics']):
            self.params['metrics'].append('CRPS_score_val')

    def on_batch_end(self, batch, logs={}):
        if (self.include_on_batch):
            logs['CRPS_score_val'] = float('-inf')

    def on_epoch_end(self, epoch, logs={}):
        logs['CRPS_score_val'] = float('-inf')
            
        if (self.validation):
            X_valid, y_valid = self.validation[0], self.validation[1]
            y_pred = self.model.predict(X_valid)
            y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
            y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
            val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * X_valid.shape[0])
            val_s = np.round(val_s, 6)
            logs['CRPS_score_val'] = val_s

# %%
def get_model(x_tr,y_tr,x_val,y_val):
    inp = Input(shape = (x_tr.shape[1],))
    x = Dense(1024, input_dim=X.shape[1], activation='relu')(inp)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    x = Dense(256, activation='relu')(x)
    x = Dropout(0.5)(x)
    x = BatchNormalization()(x)
    
    out = Dense(199, activation='softmax')(x)
    model = Model(inp,out)
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[])
    #add lookahead
#     lookahead = Lookahead(k=5, alpha=0.5) # Initialize Lookahead
#     lookahead.inject(model) # add into model

    
    es = EarlyStopping(monitor='CRPS_score_val', 
                       mode='min',
                       restore_best_weights=True, 
                       verbose=1, 
                       patience=10)

    mc = ModelCheckpoint('best_model.h5',monitor='CRPS_score_val',mode='min',
                                   save_best_only=True, verbose=1, save_weights_only=True)
    
    bsz = 1024
    steps = x_tr.shape[0]/bsz
    


    model.fit(x_tr, y_tr,callbacks=[CRPSCallback(validation = (x_val,y_val)),es,mc], epochs=100, batch_size=bsz,verbose=1)
    model.load_weights("best_model.h5")
    
    y_pred = model.predict(x_val)
    y_valid = y_val
    y_true = np.clip(np.cumsum(y_valid, axis=1), 0, 1)
    y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1)
    val_s = ((y_true - y_pred) ** 2).sum(axis=1).sum(axis=0) / (199 * x_val.shape[0])
    crps = np.round(val_s, 6)

    return model,crps

# %%
from sklearn.model_selection import train_test_split, KFold
import time

losses = []
models = []
crps_csv = []

s_time = time.time()


for k in range(2):
    kfold = KFold(5, random_state = 42 + k, shuffle = True)
    for k_fold, (tr_inds, val_inds) in enumerate(kfold.split(yards)):
        print("-----------")
        print("-----------")
        tr_x,tr_y = X[tr_inds],y[tr_inds]
        val_x,val_y = X[val_inds],y[val_inds]
        model,crps = get_model(tr_x,tr_y,val_x,val_y)
        models.append(model)
        print("the %d fold crps is %f"%((k_fold+1),crps))
        crps_csv.append(crps)
 
print("mean crps is %f"%np.mean(crps_csv))


def predict(x_te):
    model_num = len(models)
    for k,m in enumerate(models):
        if k==0:
            y_pred = m.predict(x_te,batch_size=1024)
        else:
            y_pred+=m.predict(x_te,batch_size=1024)
            
    y_pred = y_pred / model_num
    
    return y_pred
# Out:
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18536/18536 [==============================] - 3s 145us/step - loss: 5.5731
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08253, saving model to best_model.h5
# Epoch 2/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 5.0730
#
# Epoch 00002: CRPS_score_val improved from 0.08253 to 0.07766, saving model to best_model.h5
# Epoch 3/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 4.6613
#
# Epoch 00003: CRPS_score_val improved from 0.07766 to 0.06407, saving model to best_model.h5
# Epoch 4/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 4.2617
#
# Epoch 00004: CRPS_score_val improved from 0.06407 to 0.04519, saving model to best_model.h5
# Epoch 5/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 3.9023
#
# Epoch 00005: CRPS_score_val improved from 0.04519 to 0.02854, saving model to best_model.h5
# Epoch 6/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 3.5662
#
# Epoch 00006: CRPS_score_val improved from 0.02854 to 0.01969, saving model to best_model.h5
# Epoch 7/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 3.3081
#
# Epoch 00007: CRPS_score_val improved from 0.01969 to 0.01614, saving model to best_model.h5
# Epoch 8/100
# 18536/18536 [==============================] - 2s 97us/step - loss: 3.1180
#
# Epoch 00008: CRPS_score_val improved from 0.01614 to 0.01449, saving model to best_model.h5
# Epoch 9/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 3.0008
#
# Epoch 00009: CRPS_score_val improved from 0.01449 to 0.01382, saving model to best_model.h5
# Epoch 10/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.9353
#
# Epoch 00010: CRPS_score_val improved from 0.01382 to 0.01357, saving model to best_model.h5
# Epoch 11/100
# 18536/18536 [==============================] - 2s 98us/step - loss: 2.8920
#
# Epoch 00011: CRPS_score_val improved from 0.01357 to 0.01342, saving model to best_model.h5
# Epoch 12/100
# 18536/18536 [==============================] - 2s 98us/step - loss: 2.8552
#
# Epoch 00012: CRPS_score_val improved from 0.01342 to 0.01332, saving model to best_model.h5
# Epoch 13/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.8396
#
# Epoch 00013: CRPS_score_val improved from 0.01332 to 0.01327, saving model to best_model.h5
# Epoch 14/100
# 18536/18536 [==============================] - 2s 104us/step - loss: 2.8164
#
# Epoch 00014: CRPS_score_val improved from 0.01327 to 0.01319, saving model to best_model.h5
# Epoch 15/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.7978
#
# Epoch 00015: CRPS_score_val improved from 0.01319 to 0.01316, saving model to best_model.h5
# Epoch 16/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.7829
#
# Epoch 00016: CRPS_score_val improved from 0.01316 to 0.01312, saving model to best_model.h5
# Epoch 17/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7793
#
# Epoch 00017: CRPS_score_val improved from 0.01312 to 0.01310, saving model to best_model.h5
# Epoch 18/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7615
#
# Epoch 00018: CRPS_score_val improved from 0.01310 to 0.01306, saving model to best_model.h5
# Epoch 19/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7564
#
# Epoch 00019: CRPS_score_val improved from 0.01306 to 0.01302, saving model to best_model.h5
# Epoch 20/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.7487
#
# Epoch 00020: CRPS_score_val improved from 0.01302 to 0.01301, saving model to best_model.h5
# Epoch 21/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7435
#
# Epoch 00021: CRPS_score_val improved from 0.01301 to 0.01299, saving model to best_model.h5
# Epoch 22/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7351
#
# Epoch 00022: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 23/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7279
#
# Epoch 00023: CRPS_score_val improved from 0.01296 to 0.01295, saving model to best_model.h5
# Epoch 24/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7313
#
# Epoch 00024: CRPS_score_val improved from 0.01295 to 0.01294, saving model to best_model.h5
# Epoch 25/100
# 18536/18536 [==============================] - 2s 95us/step - loss: 2.7165
#
# Epoch 00025: CRPS_score_val improved from 0.01294 to 0.01293, saving model to best_model.h5
# Epoch 26/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.7168
#
# Epoch 00026: CRPS_score_val improved from 0.01293 to 0.01292, saving model to best_model.h5
# Epoch 27/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.7118
#
# Epoch 00027: CRPS_score_val improved from 0.01292 to 0.01290, saving model to best_model.h5
# Epoch 28/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.7101
#
# Epoch 00028: CRPS_score_val did not improve from 0.01290
# Epoch 29/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.7055
#
# Epoch 00029: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 30/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.7017
#
# Epoch 00030: CRPS_score_val did not improve from 0.01290
# Epoch 31/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6997
#
# Epoch 00031: CRPS_score_val did not improve from 0.01290
# Epoch 32/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6910
#
# Epoch 00032: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 33/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6944
#
# Epoch 00033: CRPS_score_val improved from 0.01289 to 0.01288, saving model to best_model.h5
# Epoch 34/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6839
#
# Epoch 00034: CRPS_score_val improved from 0.01288 to 0.01287, saving model to best_model.h5
# Epoch 35/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6843
#
# Epoch 00035: CRPS_score_val did not improve from 0.01287
# Epoch 36/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6813
#
# Epoch 00036: CRPS_score_val improved from 0.01287 to 0.01286, saving model to best_model.h5
# Epoch 37/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6832
#
# Epoch 00037: CRPS_score_val improved from 0.01286 to 0.01286, saving model to best_model.h5
# Epoch 38/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6834
#
# Epoch 00038: CRPS_score_val did not improve from 0.01286
# Epoch 39/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6746
#
# Epoch 00039: CRPS_score_val did not improve from 0.01286
# Epoch 40/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6754
#
# Epoch 00040: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 41/100
# 18536/18536 [==============================] - 2s 112us/step - loss: 2.6663
#
# Epoch 00041: CRPS_score_val improved from 0.01285 to 0.01284, saving model to best_model.h5
# Epoch 42/100
# 18536/18536 [==============================] - 2s 94us/step - loss: 2.6683
#
# Epoch 00042: CRPS_score_val did not improve from 0.01284
# Epoch 43/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6694
#
# Epoch 00043: CRPS_score_val did not improve from 0.01284
# Epoch 44/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.6631
#
# Epoch 00044: CRPS_score_val improved from 0.01284 to 0.01284, saving model to best_model.h5
# Epoch 45/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6639
#
# Epoch 00045: CRPS_score_val improved from 0.01284 to 0.01283, saving model to best_model.h5
# Epoch 46/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6598
#
# Epoch 00046: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 47/100
# 18536/18536 [==============================] - 2s 98us/step - loss: 2.6544
#
# Epoch 00047: CRPS_score_val did not improve from 0.01281
# Epoch 48/100
# 18536/18536 [==============================] - 2s 99us/step - loss: 2.6583
#
# Epoch 00048: CRPS_score_val did not improve from 0.01281
# Epoch 49/100
# 18536/18536 [==============================] - 2s 101us/step - loss: 2.6535
#
# Epoch 00049: CRPS_score_val did not improve from 0.01281
# Epoch 50/100
# 18536/18536 [==============================] - 2s 99us/step - loss: 2.6555
#
# Epoch 00050: CRPS_score_val did not improve from 0.01281
# Epoch 51/100
# 18536/18536 [==============================] - 2s 93us/step - loss: 2.6585
#
# Epoch 00051: CRPS_score_val did not improve from 0.01281
# Epoch 52/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6497
#
# Epoch 00052: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 53/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6442
#
# Epoch 00053: CRPS_score_val did not improve from 0.01280
# Epoch 54/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6450
#
# Epoch 00054: CRPS_score_val did not improve from 0.01280
# Epoch 55/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6393
#
# Epoch 00055: CRPS_score_val did not improve from 0.01280
# Epoch 56/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6404
#
# Epoch 00056: CRPS_score_val did not improve from 0.01280
# Epoch 57/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6331
#
# Epoch 00057: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 58/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6349
#
# Epoch 00058: CRPS_score_val did not improve from 0.01279
# Epoch 59/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6334
#
# Epoch 00059: CRPS_score_val did not improve from 0.01279
# Epoch 60/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6324
#
# Epoch 00060: CRPS_score_val did not improve from 0.01279
# Epoch 61/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6261
#
# Epoch 00061: CRPS_score_val improved from 0.01279 to 0.01279, saving model to best_model.h5
# Epoch 62/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6303
#
# Epoch 00062: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 63/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6223
#
# Epoch 00063: CRPS_score_val did not improve from 0.01278
# Epoch 64/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6209
#
# Epoch 00064: CRPS_score_val did not improve from 0.01278
# Epoch 65/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.6181
#
# Epoch 00065: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 66/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6192
#
# Epoch 00066: CRPS_score_val did not improve from 0.01278
# Epoch 67/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6156
#
# Epoch 00067: CRPS_score_val improved from 0.01278 to 0.01278, saving model to best_model.h5
# Epoch 68/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6139
#
# Epoch 00068: CRPS_score_val did not improve from 0.01278
# Epoch 69/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6120
#
# Epoch 00069: CRPS_score_val did not improve from 0.01278
# Epoch 70/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6086
#
# Epoch 00070: CRPS_score_val did not improve from 0.01278
# Epoch 71/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6050
#
# Epoch 00071: CRPS_score_val did not improve from 0.01278
# Epoch 72/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6066
#
# Epoch 00072: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 73/100
# 18536/18536 [==============================] - 2s 96us/step - loss: 2.6021
#
# Epoch 00073: CRPS_score_val did not improve from 0.01277
# Epoch 74/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.6084
#
# Epoch 00074: CRPS_score_val did not improve from 0.01277
# Epoch 75/100
# 18536/18536 [==============================] - 2s 100us/step - loss: 2.5987
#
# Epoch 00075: CRPS_score_val did not improve from 0.01277
# Epoch 76/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.6023
#
# Epoch 00076: CRPS_score_val did not improve from 0.01277
# Epoch 77/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.5995
#
# Epoch 00077: CRPS_score_val did not improve from 0.01277
# Epoch 78/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.5914
#
# Epoch 00078: CRPS_score_val did not improve from 0.01277
# Epoch 79/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.5936
#
# Epoch 00079: CRPS_score_val did not improve from 0.01277
# Epoch 80/100
# 18536/18536 [==============================] - 2s 92us/step - loss: 2.5888
#
# Epoch 00080: CRPS_score_val did not improve from 0.01277
# Epoch 81/100
# 18536/18536 [==============================] - 2s 91us/step - loss: 2.5858
#
# Epoch 00081: CRPS_score_val did not improve from 0.01277
# Epoch 82/100
# 18536/18536 [==============================] - 2s 90us/step - loss: 2.5896
# Restoring model weights from the end of the best epoch
#
# Epoch 00082: CRPS_score_val did not improve from 0.01277
# Epoch 00082: early stopping
# the 1 fold crps is 0.012765
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 2s 134us/step - loss: 5.5716
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08257, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 5.0644
#
# Epoch 00002: CRPS_score_val improved from 0.08257 to 0.07776, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.6501
#
# Epoch 00003: CRPS_score_val improved from 0.07776 to 0.06290, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 4.2614
#
# Epoch 00004: CRPS_score_val improved from 0.06290 to 0.04205, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.9024
#
# Epoch 00005: CRPS_score_val improved from 0.04205 to 0.02632, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.5896
#
# Epoch 00006: CRPS_score_val improved from 0.02632 to 0.01904, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.3106
#
# Epoch 00007: CRPS_score_val improved from 0.01904 to 0.01601, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.1372
#
# Epoch 00008: CRPS_score_val improved from 0.01601 to 0.01430, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.0057
#
# Epoch 00009: CRPS_score_val improved from 0.01430 to 0.01371, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.9346
#
# Epoch 00010: CRPS_score_val improved from 0.01371 to 0.01342, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.8917
#
# Epoch 00011: CRPS_score_val improved from 0.01342 to 0.01329, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8535
#
# Epoch 00012: CRPS_score_val improved from 0.01329 to 0.01322, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.8301
#
# Epoch 00013: CRPS_score_val improved from 0.01322 to 0.01318, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.8076
#
# Epoch 00014: CRPS_score_val improved from 0.01318 to 0.01314, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7971
#
# Epoch 00015: CRPS_score_val improved from 0.01314 to 0.01312, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7825
#
# Epoch 00016: CRPS_score_val improved from 0.01312 to 0.01307, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7686
#
# Epoch 00017: CRPS_score_val improved from 0.01307 to 0.01303, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7598
#
# Epoch 00018: CRPS_score_val improved from 0.01303 to 0.01300, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7502
#
# Epoch 00019: CRPS_score_val improved from 0.01300 to 0.01298, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.7430
#
# Epoch 00020: CRPS_score_val improved from 0.01298 to 0.01296, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.7370
#
# Epoch 00021: CRPS_score_val improved from 0.01296 to 0.01291, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7299
#
# Epoch 00022: CRPS_score_val improved from 0.01291 to 0.01290, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7240
#
# Epoch 00023: CRPS_score_val improved from 0.01290 to 0.01290, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7191
#
# Epoch 00024: CRPS_score_val improved from 0.01290 to 0.01289, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7106
#
# Epoch 00025: CRPS_score_val improved from 0.01289 to 0.01286, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7122
#
# Epoch 00026: CRPS_score_val improved from 0.01286 to 0.01285, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7053
#
# Epoch 00027: CRPS_score_val did not improve from 0.01285
# Epoch 28/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7098
#
# Epoch 00028: CRPS_score_val did not improve from 0.01285
# Epoch 29/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6984
#
# Epoch 00029: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6953
#
# Epoch 00030: CRPS_score_val did not improve from 0.01283
# Epoch 31/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6940
#
# Epoch 00031: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6936
#
# Epoch 00032: CRPS_score_val improved from 0.01281 to 0.01281, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6945
#
# Epoch 00033: CRPS_score_val did not improve from 0.01281
# Epoch 34/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6853
#
# Epoch 00034: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6843
#
# Epoch 00035: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6819
#
# Epoch 00036: CRPS_score_val did not improve from 0.01280
# Epoch 37/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6743
#
# Epoch 00037: CRPS_score_val improved from 0.01280 to 0.01280, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6755
#
# Epoch 00038: CRPS_score_val did not improve from 0.01280
# Epoch 39/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6742
#
# Epoch 00039: CRPS_score_val did not improve from 0.01280
# Epoch 40/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6724
#
# Epoch 00040: CRPS_score_val improved from 0.01280 to 0.01279, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6662
#
# Epoch 00041: CRPS_score_val improved from 0.01279 to 0.01277, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6593
#
# Epoch 00042: CRPS_score_val did not improve from 0.01277
# Epoch 43/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6644
#
# Epoch 00043: CRPS_score_val did not improve from 0.01277
# Epoch 44/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6616
#
# Epoch 00044: CRPS_score_val did not improve from 0.01277
# Epoch 45/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6628
#
# Epoch 00045: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6612
#
# Epoch 00046: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6584
#
# Epoch 00047: CRPS_score_val did not improve from 0.01275
# Epoch 48/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6471
#
# Epoch 00048: CRPS_score_val did not improve from 0.01275
# Epoch 49/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6547
#
# Epoch 00049: CRPS_score_val did not improve from 0.01275
# Epoch 50/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6520
#
# Epoch 00050: CRPS_score_val did not improve from 0.01275
# Epoch 51/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6457
#
# Epoch 00051: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6455
#
# Epoch 00052: CRPS_score_val did not improve from 0.01274
# Epoch 53/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6477
#
# Epoch 00053: CRPS_score_val did not improve from 0.01274
# Epoch 54/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6357
#
# Epoch 00054: CRPS_score_val did not improve from 0.01274
# Epoch 55/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6364
#
# Epoch 00055: CRPS_score_val did not improve from 0.01274
# Epoch 56/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6356
#
# Epoch 00056: CRPS_score_val did not improve from 0.01274
# Epoch 57/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6290
#
# Epoch 00057: CRPS_score_val did not improve from 0.01274
# Epoch 58/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6318
#
# Epoch 00058: CRPS_score_val did not improve from 0.01274
# Epoch 59/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6262
#
# Epoch 00059: CRPS_score_val did not improve from 0.01274
# Epoch 60/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6237
#
# Epoch 00060: CRPS_score_val did not improve from 0.01274
# Epoch 61/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6237
# Restoring model weights from the end of the best epoch
#
# Epoch 00061: CRPS_score_val did not improve from 0.01274
# Epoch 00061: early stopping
# the 2 fold crps is 0.012739
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 137us/step - loss: 5.5806
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08293, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 5.0781
#
# Epoch 00002: CRPS_score_val improved from 0.08293 to 0.07870, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.6914
#
# Epoch 00003: CRPS_score_val improved from 0.07870 to 0.06585, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.3019
#
# Epoch 00004: CRPS_score_val improved from 0.06585 to 0.04496, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.9223
#
# Epoch 00005: CRPS_score_val improved from 0.04496 to 0.02783, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.5838
#
# Epoch 00006: CRPS_score_val improved from 0.02783 to 0.01873, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.3009
#
# Epoch 00007: CRPS_score_val improved from 0.01873 to 0.01520, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.1186
#
# Epoch 00008: CRPS_score_val improved from 0.01520 to 0.01390, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 3.0014
#
# Epoch 00009: CRPS_score_val improved from 0.01390 to 0.01351, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.9319
#
# Epoch 00010: CRPS_score_val improved from 0.01351 to 0.01326, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8892
#
# Epoch 00011: CRPS_score_val improved from 0.01326 to 0.01314, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8563
#
# Epoch 00012: CRPS_score_val improved from 0.01314 to 0.01309, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8317
#
# Epoch 00013: CRPS_score_val improved from 0.01309 to 0.01304, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.8099
#
# Epoch 00014: CRPS_score_val improved from 0.01304 to 0.01299, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7911
#
# Epoch 00015: CRPS_score_val improved from 0.01299 to 0.01296, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7759
#
# Epoch 00016: CRPS_score_val improved from 0.01296 to 0.01293, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7710
#
# Epoch 00017: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7628
#
# Epoch 00018: CRPS_score_val improved from 0.01290 to 0.01287, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7529
#
# Epoch 00019: CRPS_score_val improved from 0.01287 to 0.01285, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7512
#
# Epoch 00020: CRPS_score_val improved from 0.01285 to 0.01285, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7350
#
# Epoch 00021: CRPS_score_val improved from 0.01285 to 0.01283, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7369
#
# Epoch 00022: CRPS_score_val improved from 0.01283 to 0.01281, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7215
#
# Epoch 00023: CRPS_score_val improved from 0.01281 to 0.01280, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7222
#
# Epoch 00024: CRPS_score_val improved from 0.01280 to 0.01278, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7127
#
# Epoch 00025: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7138
#
# Epoch 00026: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7063
#
# Epoch 00027: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7048
#
# Epoch 00028: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7034
#
# Epoch 00029: CRPS_score_val improved from 0.01275 to 0.01275, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6987
#
# Epoch 00030: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 31/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6947
#
# Epoch 00031: CRPS_score_val improved from 0.01274 to 0.01273, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6936
#
# Epoch 00032: CRPS_score_val did not improve from 0.01273
# Epoch 33/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6932
#
# Epoch 00033: CRPS_score_val improved from 0.01273 to 0.01273, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6893
#
# Epoch 00034: CRPS_score_val improved from 0.01273 to 0.01272, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.6827
#
# Epoch 00035: CRPS_score_val did not improve from 0.01272
# Epoch 36/100
# 18537/18537 [==============================] - 2s 115us/step - loss: 2.6810
#
# Epoch 00036: CRPS_score_val did not improve from 0.01272
# Epoch 37/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.6843
#
# Epoch 00037: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6764
#
# Epoch 00038: CRPS_score_val improved from 0.01272 to 0.01272, saving model to best_model.h5
# Epoch 39/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6727
#
# Epoch 00039: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6703
#
# Epoch 00040: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 41/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6745
#
# Epoch 00041: CRPS_score_val improved from 0.01271 to 0.01271, saving model to best_model.h5
# Epoch 42/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6639
#
# Epoch 00042: CRPS_score_val improved from 0.01271 to 0.01270, saving model to best_model.h5
# Epoch 43/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6598
#
# Epoch 00043: CRPS_score_val improved from 0.01270 to 0.01270, saving model to best_model.h5
# Epoch 44/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6641
#
# Epoch 00044: CRPS_score_val improved from 0.01270 to 0.01269, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6608
#
# Epoch 00045: CRPS_score_val improved from 0.01269 to 0.01269, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6531
#
# Epoch 00046: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 47/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6539
#
# Epoch 00047: CRPS_score_val did not improve from 0.01268
# Epoch 48/100
# 18537/18537 [==============================] - 2s 100us/step - loss: 2.6506
#
# Epoch 00048: CRPS_score_val did not improve from 0.01268
# Epoch 49/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6520
#
# Epoch 00049: CRPS_score_val did not improve from 0.01268
# Epoch 50/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6506
#
# Epoch 00050: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6474
#
# Epoch 00051: CRPS_score_val did not improve from 0.01268
# Epoch 52/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6439
#
# Epoch 00052: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6422
#
# Epoch 00053: CRPS_score_val did not improve from 0.01268
# Epoch 54/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6376
#
# Epoch 00054: CRPS_score_val did not improve from 0.01268
# Epoch 55/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6380
#
# Epoch 00055: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 56/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6321
#
# Epoch 00056: CRPS_score_val did not improve from 0.01267
# Epoch 57/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6310
#
# Epoch 00057: CRPS_score_val did not improve from 0.01267
# Epoch 58/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6252
#
# Epoch 00058: CRPS_score_val did not improve from 0.01267
# Epoch 59/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6297
#
# Epoch 00059: CRPS_score_val did not improve from 0.01267
# Epoch 60/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6279
#
# Epoch 00060: CRPS_score_val did not improve from 0.01267
# Epoch 61/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6267
#
# Epoch 00061: CRPS_score_val improved from 0.01267 to 0.01267, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6252
#
# Epoch 00062: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6231
#
# Epoch 00063: CRPS_score_val did not improve from 0.01266
# Epoch 64/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6200
#
# Epoch 00064: CRPS_score_val did not improve from 0.01266
# Epoch 65/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6150
#
# Epoch 00065: CRPS_score_val did not improve from 0.01266
# Epoch 66/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6106
#
# Epoch 00066: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 67/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6134
#
# Epoch 00067: CRPS_score_val did not improve from 0.01266
# Epoch 68/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6101
#
# Epoch 00068: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 69/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6059
#
# Epoch 00069: CRPS_score_val did not improve from 0.01266
# Epoch 70/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6032
#
# Epoch 00070: CRPS_score_val did not improve from 0.01266
# Epoch 71/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6029
#
# Epoch 00071: CRPS_score_val did not improve from 0.01266
# Epoch 72/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6024
#
# Epoch 00072: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 73/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6012
#
# Epoch 00073: CRPS_score_val did not improve from 0.01266
# Epoch 74/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5978
#
# Epoch 00074: CRPS_score_val did not improve from 0.01266
# Epoch 75/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5979
#
# Epoch 00075: CRPS_score_val did not improve from 0.01266
# Epoch 76/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5909
#
# Epoch 00076: CRPS_score_val did not improve from 0.01266
# Epoch 77/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5930
#
# Epoch 00077: CRPS_score_val did not improve from 0.01266
# Epoch 78/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5856
#
# Epoch 00078: CRPS_score_val did not improve from 0.01266
# Epoch 79/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5850
#
# Epoch 00079: CRPS_score_val did not improve from 0.01266
# Epoch 80/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5871
#
# Epoch 00080: CRPS_score_val did not improve from 0.01266
# Epoch 81/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5778
#
# Epoch 00081: CRPS_score_val did not improve from 0.01266
# Epoch 82/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5711
# Restoring model weights from the end of the best epoch
#
# Epoch 00082: CRPS_score_val did not improve from 0.01266
# Epoch 00082: early stopping
# the 3 fold crps is 0.012656
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 143us/step - loss: 5.5663
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08182, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 5.0453
#
# Epoch 00002: CRPS_score_val improved from 0.08182 to 0.07765, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 4.6237
#
# Epoch 00003: CRPS_score_val improved from 0.07765 to 0.06335, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.2362
#
# Epoch 00004: CRPS_score_val improved from 0.06335 to 0.04296, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.8924
#
# Epoch 00005: CRPS_score_val improved from 0.04296 to 0.02684, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.5602
#
# Epoch 00006: CRPS_score_val improved from 0.02684 to 0.01866, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.3097
#
# Epoch 00007: CRPS_score_val improved from 0.01866 to 0.01511, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 3.1209
#
# Epoch 00008: CRPS_score_val improved from 0.01511 to 0.01386, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.0030
#
# Epoch 00009: CRPS_score_val improved from 0.01386 to 0.01346, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.9324
#
# Epoch 00010: CRPS_score_val improved from 0.01346 to 0.01318, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8833
#
# Epoch 00011: CRPS_score_val improved from 0.01318 to 0.01310, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8524
#
# Epoch 00012: CRPS_score_val improved from 0.01310 to 0.01300, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8321
#
# Epoch 00013: CRPS_score_val improved from 0.01300 to 0.01295, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 103us/step - loss: 2.8030
#
# Epoch 00014: CRPS_score_val improved from 0.01295 to 0.01291, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 105us/step - loss: 2.7910
#
# Epoch 00015: CRPS_score_val improved from 0.01291 to 0.01287, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7781
#
# Epoch 00016: CRPS_score_val improved from 0.01287 to 0.01285, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7708
#
# Epoch 00017: CRPS_score_val improved from 0.01285 to 0.01282, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7625
#
# Epoch 00018: CRPS_score_val improved from 0.01282 to 0.01280, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 90us/step - loss: 2.7472
#
# Epoch 00019: CRPS_score_val improved from 0.01280 to 0.01277, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7382
#
# Epoch 00020: CRPS_score_val improved from 0.01277 to 0.01277, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7355
#
# Epoch 00021: CRPS_score_val improved from 0.01277 to 0.01275, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7311
#
# Epoch 00022: CRPS_score_val improved from 0.01275 to 0.01273, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7279
#
# Epoch 00023: CRPS_score_val improved from 0.01273 to 0.01271, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7234
#
# Epoch 00024: CRPS_score_val did not improve from 0.01271
# Epoch 25/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7154
#
# Epoch 00025: CRPS_score_val improved from 0.01271 to 0.01269, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7150
#
# Epoch 00026: CRPS_score_val improved from 0.01269 to 0.01268, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7053
#
# Epoch 00027: CRPS_score_val improved from 0.01268 to 0.01268, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.7039
#
# Epoch 00028: CRPS_score_val did not improve from 0.01268
# Epoch 29/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7005
#
# Epoch 00029: CRPS_score_val improved from 0.01268 to 0.01267, saving model to best_model.h5
# Epoch 30/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6998
#
# Epoch 00030: CRPS_score_val did not improve from 0.01267
# Epoch 31/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6944
#
# Epoch 00031: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 32/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6889
#
# Epoch 00032: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 33/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6930
#
# Epoch 00033: CRPS_score_val improved from 0.01265 to 0.01264, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6900
#
# Epoch 00034: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6831
#
# Epoch 00035: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 36/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6789
#
# Epoch 00036: CRPS_score_val improved from 0.01264 to 0.01264, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6797
#
# Epoch 00037: CRPS_score_val did not improve from 0.01264
# Epoch 38/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6745
#
# Epoch 00038: CRPS_score_val did not improve from 0.01264
# Epoch 39/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6762
#
# Epoch 00039: CRPS_score_val improved from 0.01264 to 0.01262, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6667
#
# Epoch 00040: CRPS_score_val did not improve from 0.01262
# Epoch 41/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6698
#
# Epoch 00041: CRPS_score_val did not improve from 0.01262
# Epoch 42/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6632
#
# Epoch 00042: CRPS_score_val did not improve from 0.01262
# Epoch 43/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6658
#
# Epoch 00043: CRPS_score_val did not improve from 0.01262
# Epoch 44/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6626
#
# Epoch 00044: CRPS_score_val improved from 0.01262 to 0.01260, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6613
#
# Epoch 00045: CRPS_score_val did not improve from 0.01260
# Epoch 46/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6551
#
# Epoch 00046: CRPS_score_val did not improve from 0.01260
# Epoch 47/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6573
#
# Epoch 00047: CRPS_score_val did not improve from 0.01260
# Epoch 48/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6574
#
# Epoch 00048: CRPS_score_val did not improve from 0.01260
# Epoch 49/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6518
#
# Epoch 00049: CRPS_score_val did not improve from 0.01260
# Epoch 50/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6491
#
# Epoch 00050: CRPS_score_val did not improve from 0.01260
# Epoch 51/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6431
#
# Epoch 00051: CRPS_score_val improved from 0.01260 to 0.01260, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6459
#
# Epoch 00052: CRPS_score_val improved from 0.01260 to 0.01259, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6424
#
# Epoch 00053: CRPS_score_val improved from 0.01259 to 0.01257, saving model to best_model.h5
# Epoch 54/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6407
#
# Epoch 00054: CRPS_score_val did not improve from 0.01257
# Epoch 55/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6377
#
# Epoch 00055: CRPS_score_val did not improve from 0.01257
# Epoch 56/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6383
#
# Epoch 00056: CRPS_score_val did not improve from 0.01257
# Epoch 57/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6358
#
# Epoch 00057: CRPS_score_val did not improve from 0.01257
# Epoch 58/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6336
#
# Epoch 00058: CRPS_score_val did not improve from 0.01257
# Epoch 59/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6304
#
# Epoch 00059: CRPS_score_val did not improve from 0.01257
# Epoch 60/100
# ...
#
# Epoch 00047: CRPS_score_val did not improve from 0.01335
# Epoch 48/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6509
#
# Epoch 00048: CRPS_score_val did not improve from 0.01335
# Epoch 49/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6442
#
# Epoch 00049: CRPS_score_val improved from 0.01335 to 0.01335, saving model to best_model.h5
# Epoch 50/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6420
#
# Epoch 00050: CRPS_score_val improved from 0.01335 to 0.01334, saving model to best_model.h5
# Epoch 51/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6394
#
# Epoch 00051: CRPS_score_val improved from 0.01334 to 0.01334, saving model to best_model.h5
# Epoch 52/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6435
#
# Epoch 00052: CRPS_score_val improved from 0.01334 to 0.01333, saving model to best_model.h5
# Epoch 53/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6365
#
# Epoch 00053: CRPS_score_val did not improve from 0.01333
# Epoch 54/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6371
#
# Epoch 00054: CRPS_score_val did not improve from 0.01333
# Epoch 55/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6342
#
# Epoch 00055: CRPS_score_val did not improve from 0.01333
# Epoch 56/100
# 18537/18537 [==============================] - 2s 102us/step - loss: 2.6300
#
# Epoch 00056: CRPS_score_val did not improve from 0.01333
# Epoch 57/100
# 18537/18537 [==============================] - 2s 104us/step - loss: 2.6306
#
# Epoch 00057: CRPS_score_val did not improve from 0.01333
# Epoch 58/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6304
#
# Epoch 00058: CRPS_score_val did not improve from 0.01333
# Epoch 59/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6294
#
# Epoch 00059: CRPS_score_val improved from 0.01333 to 0.01333, saving model to best_model.h5
# Epoch 60/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6301
#
# Epoch 00060: CRPS_score_val improved from 0.01333 to 0.01332, saving model to best_model.h5
# Epoch 61/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6223
#
# Epoch 00061: CRPS_score_val improved from 0.01332 to 0.01332, saving model to best_model.h5
# Epoch 62/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6183
#
# Epoch 00062: CRPS_score_val improved from 0.01332 to 0.01332, saving model to best_model.h5
# Epoch 63/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6164
#
# Epoch 00063: CRPS_score_val did not improve from 0.01332
# Epoch 64/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6169
#
# Epoch 00064: CRPS_score_val did not improve from 0.01332
# Epoch 65/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.6148
#
# Epoch 00065: CRPS_score_val did not improve from 0.01332
# Epoch 66/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6104
#
# Epoch 00066: CRPS_score_val improved from 0.01332 to 0.01332, saving model to best_model.h5
# Epoch 67/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6064
#
# Epoch 00067: CRPS_score_val did not improve from 0.01332
# Epoch 68/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6107
#
# Epoch 00068: CRPS_score_val improved from 0.01332 to 0.01332, saving model to best_model.h5
# Epoch 69/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6043
#
# Epoch 00069: CRPS_score_val did not improve from 0.01332
# Epoch 70/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6003
#
# Epoch 00070: CRPS_score_val did not improve from 0.01332
# Epoch 71/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5982
#
# Epoch 00071: CRPS_score_val did not improve from 0.01332
# Epoch 72/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.5980
#
# Epoch 00072: CRPS_score_val did not improve from 0.01332
# Epoch 73/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6002
#
# Epoch 00073: CRPS_score_val did not improve from 0.01332
# Epoch 74/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5907
#
# Epoch 00074: CRPS_score_val did not improve from 0.01332
# Epoch 75/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5948
#
# Epoch 00075: CRPS_score_val did not improve from 0.01332
# Epoch 76/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5892
#
# Epoch 00076: CRPS_score_val did not improve from 0.01332
# Epoch 77/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5816
#
# Epoch 00077: CRPS_score_val did not improve from 0.01332
# Epoch 78/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5826
#
# Epoch 00078: CRPS_score_val improved from 0.01332 to 0.01331, saving model to best_model.h5
# Epoch 79/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5844
#
# Epoch 00079: CRPS_score_val did not improve from 0.01331
# Epoch 80/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5823
#
# Epoch 00080: CRPS_score_val did not improve from 0.01331
# Epoch 81/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5776
#
# Epoch 00081: CRPS_score_val did not improve from 0.01331
# Epoch 82/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5738
#
# Epoch 00082: CRPS_score_val did not improve from 0.01331
# Epoch 83/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.5705
#
# Epoch 00083: CRPS_score_val did not improve from 0.01331
# Epoch 84/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.5681
#
# Epoch 00084: CRPS_score_val did not improve from 0.01331
# Epoch 85/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5661
#
# Epoch 00085: CRPS_score_val did not improve from 0.01331
# Epoch 86/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.5672
#
# Epoch 00086: CRPS_score_val did not improve from 0.01331
# Epoch 87/100
# 18537/18537 [==============================] - 2s 91us/step - loss: 2.5636
#
# Epoch 00087: CRPS_score_val did not improve from 0.01331
# Epoch 88/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.5600
# Restoring model weights from the end of the best epoch
#
# Epoch 00088: CRPS_score_val did not improve from 0.01331
# Epoch 00088: early stopping
# the 4 fold crps is 0.013312
# -----------
# -----------
# validation shape 2
# Epoch 1/100
# 18537/18537 [==============================] - 3s 181us/step - loss: 5.5864
#
# Epoch 00001: CRPS_score_val improved from inf to 0.08206, saving model to best_model.h5
# Epoch 2/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 5.0813
#
# Epoch 00002: CRPS_score_val improved from 0.08206 to 0.07801, saving model to best_model.h5
# Epoch 3/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.6855
#
# Epoch 00003: CRPS_score_val improved from 0.07801 to 0.06462, saving model to best_model.h5
# Epoch 4/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 4.2855
#
# Epoch 00004: CRPS_score_val improved from 0.06462 to 0.04406, saving model to best_model.h5
# Epoch 5/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.9065
#
# Epoch 00005: CRPS_score_val improved from 0.04406 to 0.02753, saving model to best_model.h5
# Epoch 6/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.5504
#
# Epoch 00006: CRPS_score_val improved from 0.02753 to 0.01900, saving model to best_model.h5
# Epoch 7/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 3.2944
#
# Epoch 00007: CRPS_score_val improved from 0.01900 to 0.01520, saving model to best_model.h5
# Epoch 8/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 3.1118
#
# Epoch 00008: CRPS_score_val improved from 0.01520 to 0.01410, saving model to best_model.h5
# Epoch 9/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 3.0076
#
# Epoch 00009: CRPS_score_val improved from 0.01410 to 0.01345, saving model to best_model.h5
# Epoch 10/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.9307
#
# Epoch 00010: CRPS_score_val improved from 0.01345 to 0.01327, saving model to best_model.h5
# Epoch 11/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8820
#
# Epoch 00011: CRPS_score_val improved from 0.01327 to 0.01312, saving model to best_model.h5
# Epoch 12/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.8485
#
# Epoch 00012: CRPS_score_val improved from 0.01312 to 0.01306, saving model to best_model.h5
# Epoch 13/100
# 18537/18537 [==============================] - 2s 123us/step - loss: 2.8231
#
# Epoch 00013: CRPS_score_val improved from 0.01306 to 0.01302, saving model to best_model.h5
# Epoch 14/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.8219
#
# Epoch 00014: CRPS_score_val improved from 0.01302 to 0.01297, saving model to best_model.h5
# Epoch 15/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7967
#
# Epoch 00015: CRPS_score_val improved from 0.01297 to 0.01293, saving model to best_model.h5
# Epoch 16/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7856
#
# Epoch 00016: CRPS_score_val improved from 0.01293 to 0.01290, saving model to best_model.h5
# Epoch 17/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7745
#
# Epoch 00017: CRPS_score_val improved from 0.01290 to 0.01288, saving model to best_model.h5
# Epoch 18/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7712
#
# Epoch 00018: CRPS_score_val improved from 0.01288 to 0.01286, saving model to best_model.h5
# Epoch 19/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7595
#
# Epoch 00019: CRPS_score_val improved from 0.01286 to 0.01283, saving model to best_model.h5
# Epoch 20/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7493
#
# Epoch 00020: CRPS_score_val improved from 0.01283 to 0.01282, saving model to best_model.h5
# Epoch 21/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7442
#
# Epoch 00021: CRPS_score_val improved from 0.01282 to 0.01279, saving model to best_model.h5
# Epoch 22/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7395
#
# Epoch 00022: CRPS_score_val improved from 0.01279 to 0.01278, saving model to best_model.h5
# Epoch 23/100
# 18537/18537 [==============================] - 2s 95us/step - loss: 2.7307
#
# Epoch 00023: CRPS_score_val improved from 0.01278 to 0.01277, saving model to best_model.h5
# Epoch 24/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7290
#
# Epoch 00024: CRPS_score_val improved from 0.01277 to 0.01276, saving model to best_model.h5
# Epoch 25/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.7181
#
# Epoch 00025: CRPS_score_val improved from 0.01276 to 0.01275, saving model to best_model.h5
# Epoch 26/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7197
#
# Epoch 00026: CRPS_score_val improved from 0.01275 to 0.01274, saving model to best_model.h5
# Epoch 27/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7096
#
# Epoch 00027: CRPS_score_val improved from 0.01274 to 0.01272, saving model to best_model.h5
# Epoch 28/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.7103
#
# Epoch 00028: CRPS_score_val improved from 0.01272 to 0.01271, saving model to best_model.h5
# Epoch 29/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.7046
#
# Epoch 00029: CRPS_score_val did not improve from 0.01271
# Epoch 30/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6997
#
# Epoch 00030: CRPS_score_val did not improve from 0.01271
# Epoch 31/100
# 18537/18537 [==============================] - 2s 106us/step - loss: 2.7000
#
# Epoch 00031: CRPS_score_val did not improve from 0.01271
# Epoch 32/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6966
#
# Epoch 00032: CRPS_score_val did not improve from 0.01271
# Epoch 33/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6892
#
# Epoch 00033: CRPS_score_val improved from 0.01271 to 0.01269, saving model to best_model.h5
# Epoch 34/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6924
#
# Epoch 00034: CRPS_score_val improved from 0.01269 to 0.01267, saving model to best_model.h5
# Epoch 35/100
# 18537/18537 [==============================] - 2s 92us/step - loss: 2.6886
#
# Epoch 00035: CRPS_score_val did not improve from 0.01267
# Epoch 36/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6823
#
# Epoch 00036: CRPS_score_val improved from 0.01267 to 0.01266, saving model to best_model.h5
# Epoch 37/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6797
#
# Epoch 00037: CRPS_score_val improved from 0.01266 to 0.01266, saving model to best_model.h5
# Epoch 38/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6825
#
# Epoch 00038: CRPS_score_val did not improve from 0.01266
# Epoch 39/100
# 18537/18537 [==============================] - 2s 93us/step - loss: 2.6780
#
# Epoch 00039: CRPS_score_val improved from 0.01266 to 0.01265, saving model to best_model.h5
# Epoch 40/100
# 18537/18537 [==============================] - 2s 94us/step - loss: 2.6738
#
# Epoch 00040: CRPS_score_val did not improve from 0.01265
# Epoch 41/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6677
#
# Epoch 00041: CRPS_score_val did not improve from 0.01265
# Epoch 42/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6690
#
# Epoch 00042: CRPS_score_val did not improve from 0.01265
# Epoch 43/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6700
#
# Epoch 00043: CRPS_score_val did not improve from 0.01265
# Epoch 44/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6670
#
# Epoch 00044: CRPS_score_val improved from 0.01265 to 0.01265, saving model to best_model.h5
# Epoch 45/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6627
#
# Epoch 00045: CRPS_score_val improved from 0.01265 to 0.01263, saving model to best_model.h5
# Epoch 46/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6621
#
# Epoch 00046: CRPS_score_val did not improve from 0.01263
# Epoch 47/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6618
#
# Epoch 00047: CRPS_score_val did not improve from 0.01263
# Epoch 48/100
# 18537/18537 [==============================] - 2s 97us/step - loss: 2.6593
#
# Epoch 00048: CRPS_score_val did not improve from 0.01263
# Epoch 49/100
# 18537/18537 [==============================] - 2s 96us/step - loss: 2.6540
#
# Epoch 00049: CRPS_score_val did not improve from 0.01263
# Epoch 50/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6553
#
# Epoch 00050: CRPS_score_val did not improve from 0.01263
# Epoch 51/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6502
#
# Epoch 00051: CRPS_score_val did not improve from 0.01263
# Epoch 52/100
# 18537/18537 [==============================] - 2s 98us/step - loss: 2.6473
#
# Epoch 00052: CRPS_score_val did not improve from 0.01263
# Epoch 53/100
# 18537/18537 [==============================] - 2s 99us/step - loss: 2.6454
#
# Epoch 00053: CRPS_score_val did not improve from 0.01263
# Epoch 54/100
# 18537/18537 [==============================] - 2s 111us/step - loss: 2.6480
#
# Epoch 00054: CRPS_score_val did not improve from 0.01263
# Epoch 55/100
# 18537/18537 [==============================] - 2s 112us/step - loss: 2.6473
# Restoring model weights from the end of the best epoch
#
# Epoch 00055: CRPS_score_val did not improve from 0.01263
# Epoch 00055: early stopping
# the 5 fold crps is 0.012634
# mean crps is 0.012757

# %%
print("mean crps is %f"%np.mean(crps_csv))
# Out:
# mean crps is 0.012757

# %% [markdown]
# # Time for the actual submission

# %%
# %%time
if  TRAIN_OFFLINE==False:
    from kaggle.competitions import nflrush
    env = nflrush.make_env()
    iter_test = env.iter_test()

    for (test_df, sample_prediction_df) in iter_test:
        basetable = create_features(test_df, deploy=True)
        basetable.drop(['GameId','PlayId'], axis=1, inplace=True)
        scaled_basetable = scaler.transform(basetable)

        y_pred = predict(scaled_basetable)
        y_pred = np.clip(np.cumsum(y_pred, axis=1), 0, 1).tolist()[0]

        preds_df = pd.DataFrame(data=[y_pred], columns=sample_prediction_df.columns)
        env.predict(preds_df)

    env.write_submission_file()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# ...
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Your submission file has been saved!  Once you `Commit` your Notebook and it finishes running, you can submit the file to the competition from the Notebook Viewer `Output` tab.
# CPU times: user 14min 40s, sys: 26.1 s, total: 15min 6s
# Wall time: 14min 6s
